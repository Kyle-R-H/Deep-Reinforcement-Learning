# %%
# Imports & Global Setup
import os
import torch
import pygame
import numpy as np
import torch.nn as nn
import gymnasium as gym
import torch.optim as optim
from collections import deque
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

torch.cuda.empty_cache()
os.environ['CUDA_LAUNCH_BLOCKING'] = '1' 

# Seed everything
seed = 21
np.random.seed(seed)
np.random.default_rng(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
# Out:
# c:\Code\CS4287-again\.venv\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Replay Memory

class ReplayMemory:
    def __init__(self, capacity):
        self.capacity = capacity
        
        self.states       = deque(maxlen=capacity)
        self.actions      = deque(maxlen=capacity)
        self.next_states  = deque(maxlen=capacity)
        self.rewards      = deque(maxlen=capacity)
        self.dones        = deque(maxlen=capacity)
        
    def store(self, state, action, next_state, reward, done):
        self.states.append(state)
        self.actions.append(action)
        self.next_states.append(next_state)
        self.rewards.append(reward)
        self.dones.append(done)
        
    def sample(self, batch_size):
        # np.random.seed(seed)  

        indices = np.random.choice(len(self), size=batch_size, replace=False)

        states = torch.stack([torch.as_tensor(self.states[i], dtype=torch.float32, device=device) for i in indices])
        actions = torch.as_tensor([self.actions[i] for i in indices], dtype=torch.long, device=device)
        next_states = torch.stack([torch.as_tensor(self.next_states[i], dtype=torch.float32, device=device) for i in indices])
        rewards = torch.as_tensor([self.rewards[i] for i in indices], dtype=torch.float32, device=device)
        dones = torch.as_tensor([self.dones[i] for i in indices], dtype=torch.bool, device=device)

        return states, actions, next_states, rewards, dones
    
    def __len__(self):
        return len(self.dones)

# %%
# DQN Neural Network
class DQN_Network(nn.Module):
    def __init__(self, num_actions, input_dim):
        super(DQN_Network, self).__init__()

        self.FC = nn.Sequential(
            nn.Linear(input_dim, 12),
            nn.ReLU(inplace=True),
            nn.Linear(12, 8),
            nn.ReLU(inplace=True),
            nn.Linear(8, num_actions),
        )

        for layer in [self.FC]:
            for module in layer:
                if isinstance(module, nn.Linear):
                    nn.init.kaiming_uniform_(module.weight, nonlinearity="relu")
                    nn.init.constant_(module.bias, 0.0)  # Zeros out biases

    def forward(self, x):
        return self.FC(x)

# %%
# DQN Agent

class DQN_Agent:
    def __init__(
        self,
        env,
        epsilon_max,
        epsilon_min,
        epsilon_decay,
        clip_grad_norm,
        learning_rate,
        discount,
        memory_capacity,
    ):

        self.loss_history = []
        self.running_loss = 0
        self.learned_counts = 0

        self.epsilon_max = epsilon_max
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.discount = discount

        self.action_space = env.action_space
        self.action_space.seed(seed)
        self.observation_space = env.observation_space
        self.replay_memory = ReplayMemory(memory_capacity)

        input_dim = self.observation_space.shape[0]
        output_dim = self.action_space.n

        self.main_network = DQN_Network(output_dim, input_dim).to(device)
        self.target_network = DQN_Network(output_dim, input_dim).to(device).eval()
        self.target_network.load_state_dict(self.main_network.state_dict())

        self.clip_grad_norm = clip_grad_norm

        # Huber loss 
        self.criterion = nn.SmoothL1Loss()

        self.optimizer = optim.Adam(self.main_network.parameters(), lr=learning_rate)

    def select_action(self, state):
        if np.random.random() < self.epsilon_max:
            return self.action_space.sample()

        if not torch.is_tensor(state):
            state = torch.as_tensor(state, dtype=torch.float32, device=device)

        with torch.no_grad():
            Q_values = self.main_network(state)
            return torch.argmax(Q_values).item()

    def learn(self, batch_size, done):
        states, actions, next_states, rewards, dones = self.replay_memory.sample(batch_size)

        actions = actions.unsqueeze(1)
        rewards = rewards.unsqueeze(1)
        dones = dones.unsqueeze(1)

        # Q(s,a) from main network
        predicted_q = self.main_network(states).gather(1, actions)

        with torch.no_grad():
            # Double-DQN
            next_actions = self.main_network(next_states).argmax(dim=1, keepdim=True)
            next_q_values = self.target_network(next_states).gather(1, next_actions)

            next_q_values[dones] = 0

            # final Bellman target
            y_js = rewards + (self.discount * next_q_values)

        loss = self.criterion(predicted_q, y_js)

        self.running_loss += loss.item()
        self.learned_counts += 1

        if done:
            episode_loss = self.running_loss / self.learned_counts
            self.loss_history.append(episode_loss)
            self.running_loss = 0
            self.learned_counts = 0

        self.optimizer.zero_grad()
        loss.backward() #TODO ?
        torch.nn.utils.clip_grad_norm_(self.main_network.parameters(), self.clip_grad_norm)
        self.optimizer.step()

    def hard_update(self):
        self.target_network.load_state_dict(self.main_network.state_dict())

    def update_epsilon(self, max_episodes):
        decay_amount = (self.epsilon_max - self.epsilon_min) / max_episodes
        self.epsilon_max = max(self.epsilon_min, self.epsilon_max - decay_amount)

    def save(self, path):
        torch.save(self.main_network.state_dict(), path)

# %%
# Environment Wrappers
class observation_wrapper(gym.ObservationWrapper):
    """
    Wrapper class for modifying observations in the MountainCar-v0 environment.
    """

    def __init__(self, env):
        super().__init__(env)

        self.min_value = env.observation_space.low
        self.max_value = env.observation_space.high

    def observation(self, state):
        """
        Modifies the observation by clipping the values and normalizing it.
        """
        # Min-max normalization
        normalized_state = (state - self.min_value) / ( self.max_value - self.min_value )  

        return normalized_state

class reward_wrapper(gym.RewardWrapper):
    """
    Wrapper class for modifying rewards in the MountainCar-v0 environment.
    """

    def __init__(self, env):
        super().__init__(env)

    def reward(self, state):
        """
        Modifies the reward based on the current state of the environment.
        """
        # extract the position and current velocity based on the state
        current_position, current_velocity = state

        # Interpolate the value to the desired range (because the velocity normalized value would be in range of 0 to 1 and now it would be in range of -0.5 to 0.5)
        current_velocity = np.interp(
            current_velocity, np.array([0, 1]), np.array([-0.5, 0.5])
        )

        # Calculate the modified reward based on the current position and velocity of the car.
        degree = current_position * 360
        degree2radian = np.deg2rad(degree)
        modified_reward = 0.2 * (np.cos(degree2radian) + 2 * np.abs(current_velocity))

        # Step limitation
        # Subtract 0.5 to adjust the base reward (to limit useless steps).
        modified_reward -= (0.5)

        # Check if the car has surpassed a threshold of the path and is closer to the goal
        if current_position > 0.98:
            # Add a bonus reward (Reached the goal)
            modified_reward += 20 
            
        elif current_position > 0.92:
            # So close to the goal
            modified_reward += 10  
            
        elif current_position > 0.82:
            # car is closer to the goal
            modified_reward += 6  
            
        elif current_position > 0.65:
            # car is getting close. Thus, giving reward based on the position and the further it reached
            modified_reward += 1 - np.exp(-2 * current_position) 


        # Check if the car is coming down with velocity from left and goes with full velocity to right
        initial_position = 0.40842572  # Normalized value of initial position of the car which is extracted manually

        if current_velocity > 0.3 and current_position > initial_position + 0.1:
            # Add a bonus reward for this desired behavior
            modified_reward += (1 + 2 * current_position)  

        return modified_reward

class step_wrapper(gym.Wrapper):
    """
    A wrapper class for modifying the state and reward functions of the
    MountainCar-v0 environment.
    """

    def __init__(self, env):
        """
        Initializes the StepWrapper. This is the main class for wrapping the environment with it.
        """
        # We give the env here to initialize the gym.Wrapper superclass (inherited).
        super().__init__(env) 

        self.observation_wrapper = observation_wrapper(env)
        self.reward_wrapper = reward_wrapper(env)

    def step(self, action):
        """
        Executes a step in the environment with the provided action.The reason
        behind using this method is to have access to the state and reward functions return.
        """
        #TODO: DOes it enter here?
        state, reward, done, truncation, info = self.env.step(action) # Same as before as usual

        modified_state = self.observation_wrapper.observation(state)  # Give the state to another Wrapper, which returns a modified version of state
        
        modified_reward = self.reward_wrapper.reward(modified_state)  # Give the modified state to another Wrapper to return the modified reward

        # The same returns as usual but with modified versions of the state and reward functions
        return (
            modified_state,
            modified_reward,
            done,
            truncation,
            info,
        ) 

    def reset(self, seed):
        state, info = self.env.reset(seed=seed)  # Same as before as usual
        modified_state = self.observation_wrapper.observation(state)
        return (modified_state,info,)

# %%
# ==== Model Training & Testing ====
class Model_TrainTest:
    def __init__(self, hyperparams):

        # Define RL Hyperparameters
        self.train_mode = hyperparams["train_mode"]
        self.RL_load_path = hyperparams["RL_load_path"]
        self.save_path = hyperparams["save_path"]
        self.save_interval = hyperparams["save_interval"]

        self.clip_grad_norm = hyperparams["clip_grad_norm"]
        self.learning_rate = hyperparams["learning_rate"]
        self.discount_factor = hyperparams["discount_factor"]
        self.batch_size = hyperparams["batch_size"]
        self.update_frequency = hyperparams["update_frequency"]
        self.max_episodes = hyperparams["max_episodes"]
        self.max_steps = hyperparams["max_steps"]
        self.render = hyperparams["render"]

        self.epsilon_max = hyperparams["epsilon_max"]
        self.epsilon_min = hyperparams["epsilon_min"]
        self.epsilon_decay = hyperparams["epsilon_decay"]

        self.memory_capacity = hyperparams["memory_capacity"]

        self.render_fps = hyperparams["render_fps"]

        # Define Env
        self.env = gym.make("MountainCar-v0", max_episode_steps=self.max_steps, render_mode="human" if self.render else None)
        
        # For max frame rate make it 0
        self.env.metadata["render_fps"] = self.render_fps  

        # Ignore deprecated method warnings.
        import warnings
        warnings.filterwarnings("ignore", category=UserWarning)

        # Apply RewardWrapper
        self.env = step_wrapper(self.env)

        # Define the agent class
        self.agent = DQN_Agent(
            env=self.env,
            epsilon_max=self.epsilon_max,
            epsilon_min=self.epsilon_min,
            epsilon_decay=self.epsilon_decay,
            clip_grad_norm=self.clip_grad_norm,
            learning_rate=self.learning_rate,
            discount=self.discount_factor,
            memory_capacity=self.memory_capacity,
        )

    def train(self):
        total_steps = 0
        self.reward_history = []

        # Training loop over episodes
        for episode in range(1, self.max_episodes + 1):
            state, _ = self.env.reset(seed=seed)
            done = False
            truncation = False
            step_size = 0
            episode_reward = 0

            while not done and not truncation:
                action = self.agent.select_action(state)
                next_state, reward, done, truncation, _ = self.env.step(action)

                self.agent.replay_memory.store(state, action, next_state, reward, done)

                if len(self.agent.replay_memory) > self.batch_size:
                    self.agent.learn(self.batch_size, (done or truncation))

                    # Update target-network weights
                    if total_steps % self.update_frequency == 0:
                        self.agent.hard_update()

                state = next_state
                episode_reward += reward
                step_size += 1

            # Appends for tracking history
            self.reward_history.append(episode_reward)  # episode reward
            total_steps += step_size

            # Decay epsilon at the end of each episode
            self.agent.update_epsilon(self.max_episodes)

            # based on interval
            if episode % self.save_interval == 0:
                self.agent.save(self.save_path + "_" + f"{episode}" + ".pth")
                if episode != self.max_episodes:
                    self.plot_training(episode)
                print("\nModel saved\n")

            result = (
                f"Episode: {episode}, "
                # f"Total Steps: {total_steps}, "
                f"Ep Step: {step_size}, "
                f"Raw Reward: {episode_reward:.2f}, "
                f"Epsilon: {self.agent.epsilon_max:.2f}"
            )
            print(result)
        self.plot_training(episode)

    def test(self, max_episodes):
        # Load the weights of the test_network
        self.agent.main_network.load_state_dict(torch.load(self.RL_load_path))
        self.agent.main_network.eval()

        # Testing loop over episodes
        for episode in range(1, max_episodes + 1):
            state, _ = self.env.reset(seed=seed)
            done = False
            truncation = False
            step_size = 0
            episode_reward = 200

            while not done and not truncation:
                action = self.agent.select_action(state)
                next_state, reward, done, truncation, _ = self.env.step(action)

                state = next_state
                episode_reward += reward
                step_size += 1

            # Print log
            result = (
                f"Episode: {episode}, "
                f"Steps: {step_size:}, "
                f"Reward: {episode_reward:.2f}, "
            )
            print(result)

        pygame.quit()  # close the rendering window

    def plot_training(self, episode):
        # Calculate the Simple Moving Average (SMA) with a window size of 50
        sma = np.convolve(self.reward_history, np.ones(50) / 50, mode="valid")

        # Clip max (high) values for better plot analysis
        reward_history = np.clip(self.reward_history, a_min=None, a_max=100)
        sma = np.clip(sma, a_min=None, a_max=100)

        plt.figure()
        plt.title("Obtained Rewards")
        plt.plot(reward_history, label="Raw Reward", color="#4BA754", alpha=1)
        plt.plot(sma, label="Simple Moving Average 50", color="#F08100")
        plt.xlabel("Episode")
        plt.ylabel("Rewards")
        plt.legend()

        # Only save as file if last episode
        if episode == self.max_episodes:
            plt.savefig("./reward_plot.png", format="png", dpi=600, bbox_inches="tight")
        plt.tight_layout()
        plt.grid(True)
        plt.show()
        plt.clf()
        plt.close()

        plt.figure()
        plt.title("Network Loss")
        plt.plot(self.agent.loss_history, label="Loss", color="#8921BB", alpha=1)
        plt.xlabel("Episode")
        plt.ylabel("Loss")

        # Only save as file if last episode
        if episode == self.max_episodes:
            plt.savefig("./Loss_plot.png", format="png", dpi=600, bbox_inches="tight")
        plt.tight_layout()
        plt.grid(True)
        plt.show()

# %%
# ==== Main Runner ====
if __name__ == "__main__":
    # Parameters:
    train_mode = True
    render = False
    RL_hyperparams = {
        "train_mode": train_mode,
        "RL_load_path": "./final_weights_500.pth",
        "save_path": "./final_weights",
        "save_interval": 500,
        "clip_grad_norm": 5,
        "learning_rate": 1e-4,
        "discount_factor": 0.99,
        "batch_size": 64,
        "update_frequency": 20,
        "max_episodes": 1000 if train_mode else 10,
        "max_steps": 200,
        "render": render,
        
        "epsilon_max": 0.999 if train_mode else -1,
        "epsilon_min": 0.05,
        "epsilon_decay": 0.995,
        
        "memory_capacity": 50000 if train_mode else 0,
        "render_fps": 60,
    }

    # Run
    DRL = Model_TrainTest(RL_hyperparams)  # Define the instance
    # Train
    if train_mode:
        DRL.train()
    else:
        # Test
        DRL.test(max_episodes=RL_hyperparams["max_episodes"])
# Out:
# Episode: 1, Ep Step: 200, Raw Reward: -125.52, Epsilon: 1.00
# Episode: 2, Ep Step: 200, Raw Reward: -119.66, Epsilon: 1.00
# Episode: 3, Ep Step: 200, Raw Reward: -119.00, Epsilon: 1.00
# Episode: 4, Ep Step: 200, Raw Reward: -126.24, Epsilon: 1.00
# Episode: 5, Ep Step: 200, Raw Reward: -121.33, Epsilon: 0.99
# Episode: 6, Ep Step: 200, Raw Reward: -121.18, Epsilon: 0.99
# Episode: 7, Ep Step: 200, Raw Reward: -115.96, Epsilon: 0.99
# Episode: 8, Ep Step: 200, Raw Reward: -124.61, Epsilon: 0.99
# Episode: 9, Ep Step: 200, Raw Reward: -121.30, Epsilon: 0.99
# Episode: 10, Ep Step: 200, Raw Reward: -119.98, Epsilon: 0.99
# Episode: 11, Ep Step: 200, Raw Reward: -119.41, Epsilon: 0.99
# Episode: 12, Ep Step: 200, Raw Reward: -124.98, Epsilon: 0.99
# Episode: 13, Ep Step: 200, Raw Reward: -118.90, Epsilon: 0.99
# Episode: 14, Ep Step: 200, Raw Reward: -123.47, Epsilon: 0.99
# Episode: 15, Ep Step: 200, Raw Reward: -124.94, Epsilon: 0.98
# Episode: 16, Ep Step: 200, Raw Reward: -126.35, Epsilon: 0.98
# Episode: 17, Ep Step: 200, Raw Reward: -126.07, Epsilon: 0.98
# Episode: 18, Ep Step: 200, Raw Reward: -119.11, Epsilon: 0.98
# Episode: 19, Ep Step: 200, Raw Reward: -126.27, Epsilon: 0.98
# Episode: 20, Ep Step: 200, Raw Reward: -122.97, Epsilon: 0.98
# Episode: 21, Ep Step: 200, Raw Reward: -125.57, Epsilon: 0.98
# Episode: 22, Ep Step: 200, Raw Reward: -121.29, Epsilon: 0.98
# Episode: 23, Ep Step: 200, Raw Reward: -120.42, Epsilon: 0.98
# Episode: 24, Ep Step: 200, Raw Reward: -124.81, Epsilon: 0.98
# Episode: 25, Ep Step: 200, Raw Reward: -122.23, Epsilon: 0.98
# Episode: 26, Ep Step: 200, Raw Reward: -124.41, Epsilon: 0.97
# Episode: 27, Ep Step: 200, Raw Reward: -125.12, Epsilon: 0.97
# Episode: 28, Ep Step: 200, Raw Reward: -125.39, Epsilon: 0.97
# Episode: 29, Ep Step: 200, Raw Reward: -124.12, Epsilon: 0.97
# Episode: 30, Ep Step: 200, Raw Reward: -124.04, Epsilon: 0.97
# Episode: 31, Ep Step: 200, Raw Reward: -122.90, Epsilon: 0.97
# Episode: 32, Ep Step: 200, Raw Reward: -126.88, Epsilon: 0.97
# Episode: 33, Ep Step: 200, Raw Reward: -125.06, Epsilon: 0.97
# Episode: 34, Ep Step: 200, Raw Reward: -121.82, Epsilon: 0.97
# Episode: 35, Ep Step: 200, Raw Reward: -123.42, Epsilon: 0.97
# Episode: 36, Ep Step: 200, Raw Reward: -123.17, Epsilon: 0.97
# Episode: 37, Ep Step: 200, Raw Reward: -119.99, Epsilon: 0.96
# Episode: 38, Ep Step: 200, Raw Reward: -121.30, Epsilon: 0.96
# Episode: 39, Ep Step: 200, Raw Reward: -126.32, Epsilon: 0.96
# Episode: 40, Ep Step: 200, Raw Reward: -126.92, Epsilon: 0.96
# Episode: 41, Ep Step: 200, Raw Reward: -120.02, Epsilon: 0.96
# Episode: 42, Ep Step: 200, Raw Reward: -123.87, Epsilon: 0.96
# Episode: 43, Ep Step: 200, Raw Reward: -123.60, Epsilon: 0.96
# Episode: 44, Ep Step: 200, Raw Reward: -126.58, Epsilon: 0.96
# Episode: 45, Ep Step: 200, Raw Reward: -125.31, Epsilon: 0.96
# Episode: 46, Ep Step: 200, Raw Reward: -123.58, Epsilon: 0.96
# Episode: 47, Ep Step: 200, Raw Reward: -118.95, Epsilon: 0.96
# Episode: 48, Ep Step: 200, Raw Reward: -127.16, Epsilon: 0.95
# Episode: 49, Ep Step: 200, Raw Reward: -122.31, Epsilon: 0.95
# Episode: 50, Ep Step: 200, Raw Reward: -121.64, Epsilon: 0.95
# Episode: 51, Ep Step: 200, Raw Reward: -120.95, Epsilon: 0.95
# Episode: 52, Ep Step: 200, Raw Reward: -121.70, Epsilon: 0.95
# Episode: 53, Ep Step: 200, Raw Reward: -123.21, Epsilon: 0.95
# Episode: 54, Ep Step: 200, Raw Reward: -121.04, Epsilon: 0.95
# Episode: 55, Ep Step: 200, Raw Reward: -115.30, Epsilon: 0.95
# Episode: 56, Ep Step: 200, Raw Reward: -127.85, Epsilon: 0.95
# Episode: 57, Ep Step: 200, Raw Reward: -123.12, Epsilon: 0.95
# Episode: 58, Ep Step: 200, Raw Reward: -117.28, Epsilon: 0.95
# Episode: 59, Ep Step: 200, Raw Reward: -124.59, Epsilon: 0.94
# Episode: 60, Ep Step: 200, Raw Reward: -122.47, Epsilon: 0.94
# Episode: 61, Ep Step: 200, Raw Reward: -120.18, Epsilon: 0.94
# Episode: 62, Ep Step: 200, Raw Reward: -122.73, Epsilon: 0.94
# Episode: 63, Ep Step: 200, Raw Reward: -120.83, Epsilon: 0.94
# Episode: 64, Ep Step: 200, Raw Reward: -122.71, Epsilon: 0.94
# Episode: 65, Ep Step: 200, Raw Reward: -118.16, Epsilon: 0.94
# Episode: 66, Ep Step: 200, Raw Reward: -121.66, Epsilon: 0.94
# Episode: 67, Ep Step: 200, Raw Reward: -118.49, Epsilon: 0.94
# Episode: 68, Ep Step: 200, Raw Reward: -118.85, Epsilon: 0.94
# Episode: 69, Ep Step: 200, Raw Reward: -123.55, Epsilon: 0.94
# Episode: 70, Ep Step: 200, Raw Reward: -122.97, Epsilon: 0.93
# Episode: 71, Ep Step: 200, Raw Reward: -113.53, Epsilon: 0.93
# Episode: 72, Ep Step: 200, Raw Reward: -120.79, Epsilon: 0.93
# Episode: 73, Ep Step: 200, Raw Reward: -125.65, Epsilon: 0.93
# Episode: 74, Ep Step: 200, Raw Reward: -123.31, Epsilon: 0.93
# Episode: 75, Ep Step: 200, Raw Reward: -119.16, Epsilon: 0.93
# Episode: 76, Ep Step: 200, Raw Reward: -124.07, Epsilon: 0.93
# Episode: 77, Ep Step: 200, Raw Reward: -122.43, Epsilon: 0.93
# Episode: 78, Ep Step: 200, Raw Reward: -116.55, Epsilon: 0.93
# Episode: 79, Ep Step: 200, Raw Reward: -119.10, Epsilon: 0.93
# Episode: 80, Ep Step: 200, Raw Reward: -123.03, Epsilon: 0.93
# Episode: 81, Ep Step: 200, Raw Reward: -120.77, Epsilon: 0.93
# Episode: 82, Ep Step: 200, Raw Reward: -122.32, Epsilon: 0.92
# Episode: 83, Ep Step: 200, Raw Reward: -121.37, Epsilon: 0.92
# Episode: 84, Ep Step: 200, Raw Reward: -123.94, Epsilon: 0.92
# Episode: 85, Ep Step: 200, Raw Reward: -122.50, Epsilon: 0.92
# Episode: 86, Ep Step: 200, Raw Reward: -119.44, Epsilon: 0.92
# Episode: 87, Ep Step: 200, Raw Reward: -122.01, Epsilon: 0.92
# Episode: 88, Ep Step: 200, Raw Reward: -127.46, Epsilon: 0.92
# Episode: 89, Ep Step: 200, Raw Reward: -123.63, Epsilon: 0.92
# Episode: 90, Ep Step: 200, Raw Reward: -125.52, Epsilon: 0.92
# Episode: 91, Ep Step: 200, Raw Reward: -120.68, Epsilon: 0.92
# Episode: 92, Ep Step: 200, Raw Reward: -125.25, Epsilon: 0.92
# Episode: 93, Ep Step: 200, Raw Reward: -123.29, Epsilon: 0.91
# Episode: 94, Ep Step: 200, Raw Reward: -121.07, Epsilon: 0.91
# Episode: 95, Ep Step: 200, Raw Reward: -119.98, Epsilon: 0.91
# Episode: 96, Ep Step: 200, Raw Reward: -122.16, Epsilon: 0.91
# Episode: 97, Ep Step: 200, Raw Reward: -122.59, Epsilon: 0.91
# Episode: 98, Ep Step: 200, Raw Reward: -124.39, Epsilon: 0.91
# Episode: 99, Ep Step: 200, Raw Reward: -118.63, Epsilon: 0.91
# Episode: 100, Ep Step: 200, Raw Reward: -123.48, Epsilon: 0.91
# Episode: 101, Ep Step: 200, Raw Reward: -122.09, Epsilon: 0.91
# Episode: 102, Ep Step: 200, Raw Reward: -122.39, Epsilon: 0.91
# Episode: 103, Ep Step: 200, Raw Reward: -121.31, Epsilon: 0.91
# Episode: 104, Ep Step: 200, Raw Reward: -121.40, Epsilon: 0.91
# Episode: 105, Ep Step: 200, Raw Reward: -117.74, Epsilon: 0.90
# Episode: 106, Ep Step: 200, Raw Reward: -126.41, Epsilon: 0.90
# Episode: 107, Ep Step: 200, Raw Reward: -123.82, Epsilon: 0.90
# Episode: 108, Ep Step: 200, Raw Reward: -121.08, Epsilon: 0.90
# Episode: 109, Ep Step: 200, Raw Reward: -119.57, Epsilon: 0.90
# Episode: 110, Ep Step: 200, Raw Reward: -122.32, Epsilon: 0.90
# Episode: 111, Ep Step: 200, Raw Reward: -115.48, Epsilon: 0.90
# Episode: 112, Ep Step: 200, Raw Reward: -120.30, Epsilon: 0.90
# Episode: 113, Ep Step: 200, Raw Reward: -119.73, Epsilon: 0.90
# Episode: 114, Ep Step: 200, Raw Reward: -124.06, Epsilon: 0.90
# Episode: 115, Ep Step: 200, Raw Reward: -119.20, Epsilon: 0.90
# Episode: 116, Ep Step: 200, Raw Reward: -122.57, Epsilon: 0.90
# Episode: 117, Ep Step: 200, Raw Reward: -124.08, Epsilon: 0.89
# Episode: 118, Ep Step: 200, Raw Reward: -122.53, Epsilon: 0.89
# Episode: 119, Ep Step: 200, Raw Reward: -121.86, Epsilon: 0.89
# Episode: 120, Ep Step: 200, Raw Reward: -115.22, Epsilon: 0.89
# Episode: 121, Ep Step: 200, Raw Reward: -117.63, Epsilon: 0.89
# Episode: 122, Ep Step: 200, Raw Reward: -119.66, Epsilon: 0.89
# Episode: 123, Ep Step: 200, Raw Reward: -120.95, Epsilon: 0.89
# Episode: 124, Ep Step: 200, Raw Reward: -124.01, Epsilon: 0.89
# Episode: 125, Ep Step: 200, Raw Reward: -114.87, Epsilon: 0.89
# Episode: 126, Ep Step: 200, Raw Reward: -125.83, Epsilon: 0.89
# Episode: 127, Ep Step: 200, Raw Reward: -120.55, Epsilon: 0.89
# Episode: 128, Ep Step: 200, Raw Reward: -121.70, Epsilon: 0.88
# Episode: 129, Ep Step: 200, Raw Reward: -124.40, Epsilon: 0.88
# Episode: 130, Ep Step: 200, Raw Reward: -121.03, Epsilon: 0.88
# Episode: 131, Ep Step: 200, Raw Reward: -120.63, Epsilon: 0.88
# Episode: 132, Ep Step: 200, Raw Reward: -112.29, Epsilon: 0.88
# Episode: 133, Ep Step: 200, Raw Reward: -118.68, Epsilon: 0.88
# Episode: 134, Ep Step: 200, Raw Reward: -118.12, Epsilon: 0.88
# Episode: 135, Ep Step: 200, Raw Reward: -124.34, Epsilon: 0.88
# Episode: 136, Ep Step: 200, Raw Reward: -122.30, Epsilon: 0.88
# Episode: 137, Ep Step: 200, Raw Reward: -124.36, Epsilon: 0.88
# Episode: 138, Ep Step: 200, Raw Reward: -119.73, Epsilon: 0.88
# Episode: 139, Ep Step: 200, Raw Reward: -122.04, Epsilon: 0.88
# Episode: 140, Ep Step: 200, Raw Reward: -124.08, Epsilon: 0.87
# Episode: 141, Ep Step: 200, Raw Reward: -117.78, Epsilon: 0.87
# Episode: 142, Ep Step: 200, Raw Reward: -121.86, Epsilon: 0.87
# Episode: 143, Ep Step: 200, Raw Reward: -119.82, Epsilon: 0.87
# Episode: 144, Ep Step: 200, Raw Reward: -122.21, Epsilon: 0.87
# Episode: 145, Ep Step: 200, Raw Reward: -122.16, Epsilon: 0.87
# Episode: 146, Ep Step: 200, Raw Reward: -121.04, Epsilon: 0.87
# Episode: 147, Ep Step: 200, Raw Reward: -120.02, Epsilon: 0.87
# Episode: 148, Ep Step: 200, Raw Reward: -119.10, Epsilon: 0.87
# Episode: 149, Ep Step: 200, Raw Reward: -121.42, Epsilon: 0.87
# Episode: 150, Ep Step: 200, Raw Reward: -122.84, Epsilon: 0.87
# Episode: 151, Ep Step: 200, Raw Reward: -120.49, Epsilon: 0.87
# Episode: 152, Ep Step: 200, Raw Reward: -119.41, Epsilon: 0.87
# Episode: 153, Ep Step: 200, Raw Reward: -119.06, Epsilon: 0.86
# Episode: 154, Ep Step: 200, Raw Reward: -117.95, Epsilon: 0.86
# Episode: 155, Ep Step: 200, Raw Reward: -118.60, Epsilon: 0.86
# Episode: 156, Ep Step: 200, Raw Reward: -114.05, Epsilon: 0.86
# Episode: 157, Ep Step: 200, Raw Reward: -114.55, Epsilon: 0.86
# Episode: 158, Ep Step: 200, Raw Reward: -121.18, Epsilon: 0.86
# Episode: 159, Ep Step: 200, Raw Reward: -119.07, Epsilon: 0.86
# Episode: 160, Ep Step: 200, Raw Reward: -121.25, Epsilon: 0.86
# Episode: 161, Ep Step: 200, Raw Reward: -121.18, Epsilon: 0.86
# Episode: 162, Ep Step: 200, Raw Reward: -123.49, Epsilon: 0.86
# Episode: 163, Ep Step: 200, Raw Reward: -118.38, Epsilon: 0.86
# Episode: 164, Ep Step: 200, Raw Reward: -119.87, Epsilon: 0.86
# Episode: 165, Ep Step: 200, Raw Reward: -124.48, Epsilon: 0.85
# Episode: 166, Ep Step: 200, Raw Reward: -119.60, Epsilon: 0.85
# Episode: 167, Ep Step: 200, Raw Reward: -121.97, Epsilon: 0.85
# Episode: 168, Ep Step: 200, Raw Reward: -120.92, Epsilon: 0.85
# Episode: 169, Ep Step: 200, Raw Reward: -117.77, Epsilon: 0.85
# Episode: 170, Ep Step: 200, Raw Reward: -120.91, Epsilon: 0.85
# Episode: 171, Ep Step: 200, Raw Reward: -121.00, Epsilon: 0.85
# Episode: 172, Ep Step: 200, Raw Reward: -116.38, Epsilon: 0.85
# Episode: 173, Ep Step: 200, Raw Reward: -122.14, Epsilon: 0.85
# Episode: 174, Ep Step: 200, Raw Reward: -125.02, Epsilon: 0.85
# Episode: 175, Ep Step: 200, Raw Reward: -123.62, Epsilon: 0.85
# Episode: 176, Ep Step: 200, Raw Reward: -120.07, Epsilon: 0.85
# Episode: 177, Ep Step: 200, Raw Reward: -122.81, Epsilon: 0.84
# Episode: 178, Ep Step: 200, Raw Reward: -121.31, Epsilon: 0.84
# Episode: 179, Ep Step: 200, Raw Reward: -117.52, Epsilon: 0.84
# Episode: 180, Ep Step: 200, Raw Reward: -122.76, Epsilon: 0.84
# Episode: 181, Ep Step: 200, Raw Reward: -120.18, Epsilon: 0.84
# Episode: 182, Ep Step: 200, Raw Reward: -121.57, Epsilon: 0.84
# Episode: 183, Ep Step: 200, Raw Reward: -119.37, Epsilon: 0.84
# Episode: 184, Ep Step: 200, Raw Reward: -117.58, Epsilon: 0.84
# Episode: 185, Ep Step: 200, Raw Reward: -121.62, Epsilon: 0.84
# Episode: 186, Ep Step: 200, Raw Reward: -120.05, Epsilon: 0.84
# Episode: 187, Ep Step: 200, Raw Reward: -116.34, Epsilon: 0.84
# Episode: 188, Ep Step: 200, Raw Reward: -119.65, Epsilon: 0.84
# Episode: 189, Ep Step: 200, Raw Reward: -121.06, Epsilon: 0.84
# Episode: 190, Ep Step: 200, Raw Reward: -121.80, Epsilon: 0.83
# Episode: 191, Ep Step: 200, Raw Reward: -120.61, Epsilon: 0.83
# Episode: 192, Ep Step: 200, Raw Reward: -117.28, Epsilon: 0.83
# Episode: 193, Ep Step: 200, Raw Reward: -119.42, Epsilon: 0.83
# Episode: 194, Ep Step: 200, Raw Reward: -123.08, Epsilon: 0.83
# Episode: 195, Ep Step: 200, Raw Reward: -123.63, Epsilon: 0.83
# Episode: 196, Ep Step: 200, Raw Reward: -122.15, Epsilon: 0.83
# Episode: 197, Ep Step: 200, Raw Reward: -114.91, Epsilon: 0.83
# Episode: 198, Ep Step: 200, Raw Reward: -121.03, Epsilon: 0.83
# Episode: 199, Ep Step: 200, Raw Reward: -121.77, Epsilon: 0.83
# Episode: 200, Ep Step: 200, Raw Reward: -119.90, Epsilon: 0.83
# Episode: 201, Ep Step: 200, Raw Reward: -122.49, Epsilon: 0.83
# Episode: 202, Ep Step: 200, Raw Reward: -120.28, Epsilon: 0.83
# Episode: 203, Ep Step: 200, Raw Reward: -118.15, Epsilon: 0.82
# Episode: 204, Ep Step: 200, Raw Reward: -122.52, Epsilon: 0.82
# Episode: 205, Ep Step: 200, Raw Reward: -119.75, Epsilon: 0.82
# Episode: 206, Ep Step: 200, Raw Reward: -118.99, Epsilon: 0.82
# Episode: 207, Ep Step: 200, Raw Reward: -119.07, Epsilon: 0.82
# Episode: 208, Ep Step: 200, Raw Reward: -112.18, Epsilon: 0.82
# Episode: 209, Ep Step: 200, Raw Reward: -117.41, Epsilon: 0.82
# Episode: 210, Ep Step: 200, Raw Reward: -117.62, Epsilon: 0.82
# Episode: 211, Ep Step: 200, Raw Reward: -119.75, Epsilon: 0.82
# Episode: 212, Ep Step: 200, Raw Reward: -124.47, Epsilon: 0.82
# Episode: 213, Ep Step: 200, Raw Reward: -121.75, Epsilon: 0.82
# Episode: 214, Ep Step: 200, Raw Reward: -114.00, Epsilon: 0.82
# Episode: 215, Ep Step: 200, Raw Reward: -116.15, Epsilon: 0.82
# Episode: 216, Ep Step: 200, Raw Reward: -115.55, Epsilon: 0.81
# Episode: 217, Ep Step: 200, Raw Reward: -120.03, Epsilon: 0.81
# Episode: 218, Ep Step: 200, Raw Reward: -111.97, Epsilon: 0.81
# Episode: 219, Ep Step: 200, Raw Reward: -114.61, Epsilon: 0.81
# Episode: 220, Ep Step: 200, Raw Reward: -121.87, Epsilon: 0.81
# Episode: 221, Ep Step: 200, Raw Reward: -123.01, Epsilon: 0.81
# Episode: 222, Ep Step: 200, Raw Reward: -119.20, Epsilon: 0.81
# Episode: 223, Ep Step: 200, Raw Reward: -122.43, Epsilon: 0.81
# Episode: 224, Ep Step: 200, Raw Reward: -116.45, Epsilon: 0.81
# Episode: 225, Ep Step: 200, Raw Reward: -122.72, Epsilon: 0.81
# Episode: 226, Ep Step: 200, Raw Reward: -119.05, Epsilon: 0.81
# Episode: 227, Ep Step: 200, Raw Reward: -111.95, Epsilon: 0.81
# Episode: 228, Ep Step: 200, Raw Reward: -124.27, Epsilon: 0.81
# Episode: 229, Ep Step: 200, Raw Reward: -121.35, Epsilon: 0.80
# Episode: 230, Ep Step: 200, Raw Reward: -122.08, Epsilon: 0.80
# Episode: 231, Ep Step: 200, Raw Reward: -121.27, Epsilon: 0.80
# Episode: 232, Ep Step: 200, Raw Reward: -119.51, Epsilon: 0.80
# Episode: 233, Ep Step: 200, Raw Reward: -122.08, Epsilon: 0.80
# Episode: 234, Ep Step: 200, Raw Reward: -109.82, Epsilon: 0.80
# Episode: 235, Ep Step: 200, Raw Reward: -120.91, Epsilon: 0.80
# Episode: 236, Ep Step: 200, Raw Reward: -119.57, Epsilon: 0.80
# Episode: 237, Ep Step: 200, Raw Reward: -119.76, Epsilon: 0.80
# Episode: 238, Ep Step: 200, Raw Reward: -111.75, Epsilon: 0.80
# Episode: 239, Ep Step: 200, Raw Reward: -123.77, Epsilon: 0.80
# Episode: 240, Ep Step: 200, Raw Reward: -118.94, Epsilon: 0.80
# Episode: 241, Ep Step: 200, Raw Reward: -120.79, Epsilon: 0.80
# Episode: 242, Ep Step: 200, Raw Reward: -118.48, Epsilon: 0.79
# Episode: 243, Ep Step: 200, Raw Reward: -122.89, Epsilon: 0.79
# Episode: 244, Ep Step: 200, Raw Reward: -114.04, Epsilon: 0.79
# Episode: 245, Ep Step: 200, Raw Reward: -119.12, Epsilon: 0.79
# Episode: 246, Ep Step: 200, Raw Reward: -114.75, Epsilon: 0.79
# Episode: 247, Ep Step: 200, Raw Reward: -112.92, Epsilon: 0.79
# Episode: 248, Ep Step: 200, Raw Reward: -117.51, Epsilon: 0.79
# Episode: 249, Ep Step: 200, Raw Reward: -119.64, Epsilon: 0.79
# Episode: 250, Ep Step: 200, Raw Reward: -121.49, Epsilon: 0.79
# Episode: 251, Ep Step: 200, Raw Reward: -116.72, Epsilon: 0.79
# Episode: 252, Ep Step: 200, Raw Reward: -114.34, Epsilon: 0.79
# Episode: 253, Ep Step: 200, Raw Reward: -117.50, Epsilon: 0.79
# Episode: 254, Ep Step: 200, Raw Reward: -120.14, Epsilon: 0.79
# Episode: 255, Ep Step: 200, Raw Reward: -121.25, Epsilon: 0.79
# Episode: 256, Ep Step: 200, Raw Reward: -117.79, Epsilon: 0.78
# Episode: 257, Ep Step: 200, Raw Reward: -106.57, Epsilon: 0.78
# Episode: 258, Ep Step: 200, Raw Reward: -115.96, Epsilon: 0.78
# Episode: 259, Ep Step: 200, Raw Reward: -122.51, Epsilon: 0.78
# Episode: 260, Ep Step: 200, Raw Reward: -112.54, Epsilon: 0.78
# Episode: 261, Ep Step: 200, Raw Reward: -119.42, Epsilon: 0.78
# Episode: 262, Ep Step: 200, Raw Reward: -116.61, Epsilon: 0.78
# Episode: 263, Ep Step: 200, Raw Reward: -120.76, Epsilon: 0.78
# Episode: 264, Ep Step: 200, Raw Reward: -118.50, Epsilon: 0.78
# Episode: 265, Ep Step: 200, Raw Reward: -115.77, Epsilon: 0.78
# Episode: 266, Ep Step: 200, Raw Reward: -116.57, Epsilon: 0.78
# Episode: 267, Ep Step: 200, Raw Reward: -122.44, Epsilon: 0.78
# Episode: 268, Ep Step: 200, Raw Reward: -121.98, Epsilon: 0.78
# Episode: 269, Ep Step: 200, Raw Reward: -121.56, Epsilon: 0.78
# Episode: 270, Ep Step: 200, Raw Reward: -116.36, Epsilon: 0.77
# Episode: 271, Ep Step: 200, Raw Reward: -113.38, Epsilon: 0.77
# Episode: 272, Ep Step: 200, Raw Reward: -112.20, Epsilon: 0.77
# Episode: 273, Ep Step: 200, Raw Reward: -113.29, Epsilon: 0.77
# Episode: 274, Ep Step: 200, Raw Reward: -120.97, Epsilon: 0.77
# Episode: 275, Ep Step: 200, Raw Reward: -112.31, Epsilon: 0.77
# Episode: 276, Ep Step: 200, Raw Reward: -114.57, Epsilon: 0.77
# Episode: 277, Ep Step: 200, Raw Reward: -113.59, Epsilon: 0.77
# Episode: 278, Ep Step: 200, Raw Reward: -120.49, Epsilon: 0.77
# Episode: 279, Ep Step: 200, Raw Reward: -117.40, Epsilon: 0.77
# Episode: 280, Ep Step: 200, Raw Reward: -105.98, Epsilon: 0.77
# Episode: 281, Ep Step: 200, Raw Reward: -123.37, Epsilon: 0.77
# Episode: 282, Ep Step: 200, Raw Reward: -118.34, Epsilon: 0.77
# Episode: 283, Ep Step: 200, Raw Reward: -108.23, Epsilon: 0.76
# Episode: 284, Ep Step: 200, Raw Reward: -121.56, Epsilon: 0.76
# Episode: 285, Ep Step: 200, Raw Reward: -116.47, Epsilon: 0.76
# Episode: 286, Ep Step: 200, Raw Reward: -112.57, Epsilon: 0.76
# Episode: 287, Ep Step: 200, Raw Reward: -115.86, Epsilon: 0.76
# Episode: 288, Ep Step: 200, Raw Reward: -116.70, Epsilon: 0.76
# Episode: 289, Ep Step: 200, Raw Reward: -119.58, Epsilon: 0.76
# Episode: 290, Ep Step: 200, Raw Reward: -114.63, Epsilon: 0.76
# Episode: 291, Ep Step: 200, Raw Reward: -113.40, Epsilon: 0.76
# Episode: 292, Ep Step: 200, Raw Reward: -120.76, Epsilon: 0.76
# Episode: 293, Ep Step: 200, Raw Reward: -120.92, Epsilon: 0.76
# Episode: 294, Ep Step: 200, Raw Reward: -116.42, Epsilon: 0.76
# Episode: 295, Ep Step: 200, Raw Reward: -112.23, Epsilon: 0.76
# Episode: 296, Ep Step: 200, Raw Reward: -113.45, Epsilon: 0.76
# Episode: 297, Ep Step: 200, Raw Reward: -121.46, Epsilon: 0.76
# Episode: 298, Ep Step: 200, Raw Reward: -114.42, Epsilon: 0.75
# Episode: 299, Ep Step: 200, Raw Reward: -107.77, Epsilon: 0.75
# Episode: 300, Ep Step: 200, Raw Reward: -122.98, Epsilon: 0.75
# Episode: 301, Ep Step: 200, Raw Reward: -113.28, Epsilon: 0.75
# Episode: 302, Ep Step: 200, Raw Reward: -119.20, Epsilon: 0.75
# Episode: 303, Ep Step: 200, Raw Reward: -111.73, Epsilon: 0.75
# Episode: 304, Ep Step: 200, Raw Reward: -120.11, Epsilon: 0.75
# Episode: 305, Ep Step: 200, Raw Reward: -117.38, Epsilon: 0.75
# Episode: 306, Ep Step: 200, Raw Reward: -110.39, Epsilon: 0.75
# Episode: 307, Ep Step: 200, Raw Reward: -113.42, Epsilon: 0.75
# Episode: 308, Ep Step: 200, Raw Reward: -119.18, Epsilon: 0.75
# Episode: 309, Ep Step: 200, Raw Reward: -111.59, Epsilon: 0.75
# Episode: 310, Ep Step: 200, Raw Reward: -118.55, Epsilon: 0.75
# Episode: 311, Ep Step: 200, Raw Reward: -118.01, Epsilon: 0.75
# Episode: 312, Ep Step: 200, Raw Reward: -113.59, Epsilon: 0.74
# Episode: 313, Ep Step: 200, Raw Reward: -115.45, Epsilon: 0.74
# Episode: 314, Ep Step: 200, Raw Reward: -125.43, Epsilon: 0.74
# Episode: 315, Ep Step: 200, Raw Reward: -128.13, Epsilon: 0.74
# Episode: 316, Ep Step: 200, Raw Reward: -123.82, Epsilon: 0.74
# Episode: 317, Ep Step: 200, Raw Reward: -131.15, Epsilon: 0.74
# Episode: 318, Ep Step: 200, Raw Reward: -127.97, Epsilon: 0.74
# Episode: 319, Ep Step: 200, Raw Reward: -125.14, Epsilon: 0.74
# Episode: 320, Ep Step: 200, Raw Reward: -125.86, Epsilon: 0.74
# Episode: 321, Ep Step: 200, Raw Reward: -124.46, Epsilon: 0.74
# Episode: 322, Ep Step: 200, Raw Reward: -130.23, Epsilon: 0.74
# Episode: 323, Ep Step: 200, Raw Reward: -124.35, Epsilon: 0.74
# Episode: 324, Ep Step: 200, Raw Reward: -129.55, Epsilon: 0.74
# Episode: 325, Ep Step: 200, Raw Reward: -126.64, Epsilon: 0.74
# Episode: 326, Ep Step: 200, Raw Reward: -124.75, Epsilon: 0.73
# Episode: 327, Ep Step: 200, Raw Reward: -130.22, Epsilon: 0.73
# Episode: 328, Ep Step: 200, Raw Reward: -130.36, Epsilon: 0.73
# Episode: 329, Ep Step: 200, Raw Reward: -119.11, Epsilon: 0.73
# Episode: 330, Ep Step: 200, Raw Reward: -127.87, Epsilon: 0.73
# Episode: 331, Ep Step: 200, Raw Reward: -127.68, Epsilon: 0.73
# Episode: 332, Ep Step: 200, Raw Reward: -128.93, Epsilon: 0.73
# Episode: 333, Ep Step: 200, Raw Reward: -118.19, Epsilon: 0.73
# Episode: 334, Ep Step: 200, Raw Reward: -130.72, Epsilon: 0.73
# Episode: 335, Ep Step: 200, Raw Reward: -123.68, Epsilon: 0.73
# Episode: 336, Ep Step: 200, Raw Reward: -118.90, Epsilon: 0.73
# Episode: 337, Ep Step: 200, Raw Reward: -118.97, Epsilon: 0.73
# Episode: 338, Ep Step: 200, Raw Reward: -117.48, Epsilon: 0.73
# Episode: 339, Ep Step: 200, Raw Reward: -124.17, Epsilon: 0.73
# Episode: 340, Ep Step: 200, Raw Reward: -121.47, Epsilon: 0.73
# Episode: 341, Ep Step: 200, Raw Reward: -119.28, Epsilon: 0.72
# Episode: 342, Ep Step: 200, Raw Reward: -119.58, Epsilon: 0.72
# Episode: 343, Ep Step: 200, Raw Reward: -123.19, Epsilon: 0.72
# Episode: 344, Ep Step: 200, Raw Reward: -116.35, Epsilon: 0.72
# Episode: 345, Ep Step: 200, Raw Reward: -121.77, Epsilon: 0.72
# Episode: 346, Ep Step: 200, Raw Reward: -117.68, Epsilon: 0.72
# Episode: 347, Ep Step: 200, Raw Reward: -111.20, Epsilon: 0.72
# Episode: 348, Ep Step: 200, Raw Reward: -108.15, Epsilon: 0.72
# Episode: 349, Ep Step: 200, Raw Reward: -113.57, Epsilon: 0.72
# Episode: 350, Ep Step: 200, Raw Reward: -111.59, Epsilon: 0.72
# Episode: 351, Ep Step: 200, Raw Reward: -110.21, Epsilon: 0.72
# Episode: 352, Ep Step: 200, Raw Reward: -114.83, Epsilon: 0.72
# Episode: 353, Ep Step: 200, Raw Reward: -123.12, Epsilon: 0.72
# Episode: 354, Ep Step: 200, Raw Reward: -117.45, Epsilon: 0.72
# Episode: 355, Ep Step: 200, Raw Reward: -120.48, Epsilon: 0.72
# Episode: 356, Ep Step: 200, Raw Reward: -114.10, Epsilon: 0.71
# Episode: 357, Ep Step: 200, Raw Reward: -107.12, Epsilon: 0.71
# Episode: 358, Ep Step: 200, Raw Reward: -120.14, Epsilon: 0.71
# Episode: 359, Ep Step: 200, Raw Reward: -114.84, Epsilon: 0.71
# Episode: 360, Ep Step: 200, Raw Reward: -106.14, Epsilon: 0.71
# Episode: 361, Ep Step: 200, Raw Reward: -113.19, Epsilon: 0.71
# Episode: 362, Ep Step: 200, Raw Reward: -118.86, Epsilon: 0.71
# Episode: 363, Ep Step: 200, Raw Reward: -106.44, Epsilon: 0.71
# Episode: 364, Ep Step: 200, Raw Reward: -121.04, Epsilon: 0.71
# Episode: 365, Ep Step: 200, Raw Reward: -122.04, Epsilon: 0.71
# Episode: 366, Ep Step: 200, Raw Reward: -114.27, Epsilon: 0.71
# Episode: 367, Ep Step: 200, Raw Reward: -121.02, Epsilon: 0.71
# Episode: 368, Ep Step: 200, Raw Reward: -118.63, Epsilon: 0.71
# Episode: 369, Ep Step: 200, Raw Reward: -109.88, Epsilon: 0.71
# Episode: 370, Ep Step: 200, Raw Reward: -115.98, Epsilon: 0.71
# Episode: 371, Ep Step: 200, Raw Reward: -118.94, Epsilon: 0.70
# Episode: 372, Ep Step: 200, Raw Reward: -105.20, Epsilon: 0.70
# Episode: 373, Ep Step: 200, Raw Reward: -109.02, Epsilon: 0.70
# Episode: 374, Ep Step: 200, Raw Reward: -115.87, Epsilon: 0.70
# Episode: 375, Ep Step: 200, Raw Reward: -120.85, Epsilon: 0.70
# Episode: 376, Ep Step: 200, Raw Reward: -114.82, Epsilon: 0.70
# Episode: 377, Ep Step: 200, Raw Reward: -121.61, Epsilon: 0.70
# Episode: 378, Ep Step: 200, Raw Reward: -115.25, Epsilon: 0.70
# Episode: 379, Ep Step: 200, Raw Reward: -115.71, Epsilon: 0.70
# Episode: 380, Ep Step: 200, Raw Reward: -115.80, Epsilon: 0.70
# Episode: 381, Ep Step: 200, Raw Reward: -117.20, Epsilon: 0.70
# Episode: 382, Ep Step: 200, Raw Reward: -112.93, Epsilon: 0.70
# Episode: 383, Ep Step: 200, Raw Reward: -113.84, Epsilon: 0.70
# Episode: 384, Ep Step: 200, Raw Reward: -116.95, Epsilon: 0.70
# Episode: 385, Ep Step: 200, Raw Reward: -121.93, Epsilon: 0.70
# Episode: 386, Ep Step: 200, Raw Reward: -116.65, Epsilon: 0.69
# Episode: 387, Ep Step: 200, Raw Reward: -115.39, Epsilon: 0.69
# Episode: 388, Ep Step: 200, Raw Reward: -107.92, Epsilon: 0.69
# Episode: 389, Ep Step: 200, Raw Reward: -110.78, Epsilon: 0.69
# Episode: 390, Ep Step: 200, Raw Reward: -119.79, Epsilon: 0.69
# Episode: 391, Ep Step: 200, Raw Reward: -117.65, Epsilon: 0.69
# Episode: 392, Ep Step: 200, Raw Reward: -109.78, Epsilon: 0.69
# Episode: 393, Ep Step: 200, Raw Reward: -115.15, Epsilon: 0.69
# Episode: 394, Ep Step: 200, Raw Reward: -113.59, Epsilon: 0.69
# Episode: 395, Ep Step: 200, Raw Reward: -118.84, Epsilon: 0.69
# Episode: 396, Ep Step: 200, Raw Reward: -112.63, Epsilon: 0.69
# Episode: 397, Ep Step: 200, Raw Reward: -109.28, Epsilon: 0.69
# Episode: 398, Ep Step: 200, Raw Reward: -112.14, Epsilon: 0.69
# Episode: 399, Ep Step: 200, Raw Reward: -114.57, Epsilon: 0.69
# Episode: 400, Ep Step: 200, Raw Reward: -109.49, Epsilon: 0.69
# Episode: 401, Ep Step: 200, Raw Reward: -121.14, Epsilon: 0.69
# Episode: 402, Ep Step: 200, Raw Reward: -116.35, Epsilon: 0.68
# Episode: 403, Ep Step: 200, Raw Reward: -116.96, Epsilon: 0.68
# Episode: 404, Ep Step: 200, Raw Reward: -118.86, Epsilon: 0.68
# Episode: 405, Ep Step: 200, Raw Reward: -117.49, Epsilon: 0.68
# Episode: 406, Ep Step: 200, Raw Reward: -121.92, Epsilon: 0.68
# Episode: 407, Ep Step: 200, Raw Reward: -110.06, Epsilon: 0.68
# Episode: 408, Ep Step: 200, Raw Reward: -106.74, Epsilon: 0.68
# Episode: 409, Ep Step: 200, Raw Reward: -117.91, Epsilon: 0.68
# Episode: 410, Ep Step: 200, Raw Reward: -112.68, Epsilon: 0.68
# Episode: 411, Ep Step: 200, Raw Reward: -118.16, Epsilon: 0.68
# Episode: 412, Ep Step: 200, Raw Reward: -120.45, Epsilon: 0.68
# Episode: 413, Ep Step: 200, Raw Reward: -120.11, Epsilon: 0.68
# Episode: 414, Ep Step: 200, Raw Reward: -111.42, Epsilon: 0.68
# Episode: 415, Ep Step: 200, Raw Reward: -113.14, Epsilon: 0.68
# Episode: 416, Ep Step: 200, Raw Reward: -113.41, Epsilon: 0.68
# Episode: 417, Ep Step: 200, Raw Reward: -119.17, Epsilon: 0.68
# Episode: 418, Ep Step: 200, Raw Reward: -108.24, Epsilon: 0.67
# Episode: 419, Ep Step: 200, Raw Reward: -120.40, Epsilon: 0.67
# Episode: 420, Ep Step: 200, Raw Reward: -110.58, Epsilon: 0.67
# Episode: 421, Ep Step: 200, Raw Reward: -118.81, Epsilon: 0.67
# Episode: 422, Ep Step: 200, Raw Reward: -120.59, Epsilon: 0.67
# Episode: 423, Ep Step: 200, Raw Reward: -118.16, Epsilon: 0.67
# Episode: 424, Ep Step: 200, Raw Reward: -117.13, Epsilon: 0.67
# Episode: 425, Ep Step: 200, Raw Reward: -121.59, Epsilon: 0.67
# Episode: 426, Ep Step: 200, Raw Reward: -104.71, Epsilon: 0.67
# Episode: 427, Ep Step: 200, Raw Reward: -117.83, Epsilon: 0.67
# Episode: 428, Ep Step: 200, Raw Reward: -118.51, Epsilon: 0.67
# Episode: 429, Ep Step: 200, Raw Reward: -116.09, Epsilon: 0.67
# Episode: 430, Ep Step: 200, Raw Reward: -121.33, Epsilon: 0.67
# Episode: 431, Ep Step: 200, Raw Reward: -120.11, Epsilon: 0.67
# Episode: 432, Ep Step: 200, Raw Reward: -114.57, Epsilon: 0.67
# Episode: 433, Ep Step: 200, Raw Reward: -110.92, Epsilon: 0.67
# Episode: 434, Ep Step: 200, Raw Reward: -118.98, Epsilon: 0.66
# Episode: 435, Ep Step: 200, Raw Reward: -109.89, Epsilon: 0.66
# Episode: 436, Ep Step: 200, Raw Reward: -107.22, Epsilon: 0.66
# Episode: 437, Ep Step: 200, Raw Reward: -114.71, Epsilon: 0.66
# Episode: 438, Ep Step: 200, Raw Reward: -120.47, Epsilon: 0.66
# Episode: 439, Ep Step: 200, Raw Reward: -112.58, Epsilon: 0.66
# Episode: 440, Ep Step: 200, Raw Reward: -119.79, Epsilon: 0.66
# Episode: 441, Ep Step: 200, Raw Reward: -116.68, Epsilon: 0.66
# Episode: 442, Ep Step: 200, Raw Reward: -119.82, Epsilon: 0.66
# Episode: 443, Ep Step: 200, Raw Reward: -109.86, Epsilon: 0.66
# Episode: 444, Ep Step: 200, Raw Reward: -108.23, Epsilon: 0.66
# Episode: 445, Ep Step: 200, Raw Reward: -119.77, Epsilon: 0.66
# Episode: 446, Ep Step: 200, Raw Reward: -118.31, Epsilon: 0.66
# Episode: 447, Ep Step: 200, Raw Reward: -109.36, Epsilon: 0.66
# Episode: 448, Ep Step: 200, Raw Reward: -111.13, Epsilon: 0.66
# Episode: 449, Ep Step: 200, Raw Reward: -121.53, Epsilon: 0.66
# Episode: 450, Ep Step: 200, Raw Reward: -121.46, Epsilon: 0.65
# Episode: 451, Ep Step: 200, Raw Reward: -114.63, Epsilon: 0.65
# Episode: 452, Ep Step: 200, Raw Reward: -118.20, Epsilon: 0.65
# Episode: 453, Ep Step: 200, Raw Reward: -114.46, Epsilon: 0.65
# Episode: 454, Ep Step: 200, Raw Reward: -111.38, Epsilon: 0.65
# Episode: 455, Ep Step: 200, Raw Reward: -114.31, Epsilon: 0.65
# Episode: 456, Ep Step: 200, Raw Reward: -121.36, Epsilon: 0.65
# Episode: 457, Ep Step: 200, Raw Reward: -109.07, Epsilon: 0.65
# Episode: 458, Ep Step: 200, Raw Reward: -112.88, Epsilon: 0.65
# Episode: 459, Ep Step: 200, Raw Reward: -117.21, Epsilon: 0.65
# Episode: 460, Ep Step: 200, Raw Reward: -113.26, Epsilon: 0.65
# Episode: 461, Ep Step: 200, Raw Reward: -112.50, Epsilon: 0.65
# Episode: 462, Ep Step: 200, Raw Reward: -119.61, Epsilon: 0.65
# Episode: 463, Ep Step: 200, Raw Reward: -120.03, Epsilon: 0.65
# Episode: 464, Ep Step: 200, Raw Reward: -118.32, Epsilon: 0.65
# Episode: 465, Ep Step: 200, Raw Reward: -119.32, Epsilon: 0.65
# Episode: 466, Ep Step: 200, Raw Reward: -114.69, Epsilon: 0.65
# Episode: 467, Ep Step: 200, Raw Reward: -117.45, Epsilon: 0.64
# Episode: 468, Ep Step: 200, Raw Reward: -117.61, Epsilon: 0.64
# Episode: 469, Ep Step: 200, Raw Reward: -113.58, Epsilon: 0.64
# Episode: 470, Ep Step: 200, Raw Reward: -116.46, Epsilon: 0.64
# Episode: 471, Ep Step: 200, Raw Reward: -115.84, Epsilon: 0.64
# Episode: 472, Ep Step: 200, Raw Reward: -118.69, Epsilon: 0.64
# Episode: 473, Ep Step: 200, Raw Reward: -119.11, Epsilon: 0.64
# Episode: 474, Ep Step: 200, Raw Reward: -112.99, Epsilon: 0.64
# Episode: 475, Ep Step: 200, Raw Reward: -114.92, Epsilon: 0.64
# Episode: 476, Ep Step: 200, Raw Reward: -114.03, Epsilon: 0.64
# Episode: 477, Ep Step: 200, Raw Reward: -107.60, Epsilon: 0.64
# Episode: 478, Ep Step: 200, Raw Reward: -118.40, Epsilon: 0.64
# Episode: 479, Ep Step: 200, Raw Reward: -117.45, Epsilon: 0.64
# Episode: 480, Ep Step: 200, Raw Reward: -115.12, Epsilon: 0.64
# Episode: 481, Ep Step: 200, Raw Reward: -121.04, Epsilon: 0.64
# Episode: 482, Ep Step: 200, Raw Reward: -120.97, Epsilon: 0.64
# Episode: 483, Ep Step: 200, Raw Reward: -116.19, Epsilon: 0.64
# Episode: 484, Ep Step: 200, Raw Reward: -114.28, Epsilon: 0.63
# Episode: 485, Ep Step: 200, Raw Reward: -117.87, Epsilon: 0.63
# Episode: 486, Ep Step: 200, Raw Reward: -114.89, Epsilon: 0.63
# Episode: 487, Ep Step: 200, Raw Reward: -107.90, Epsilon: 0.63
# Episode: 488, Ep Step: 200, Raw Reward: -107.79, Epsilon: 0.63
# Episode: 489, Ep Step: 200, Raw Reward: -111.31, Epsilon: 0.63
# Episode: 490, Ep Step: 200, Raw Reward: -114.44, Epsilon: 0.63
# Episode: 491, Ep Step: 200, Raw Reward: -120.15, Epsilon: 0.63
# Episode: 492, Ep Step: 200, Raw Reward: -115.79, Epsilon: 0.63
# Episode: 493, Ep Step: 200, Raw Reward: -103.55, Epsilon: 0.63
# Episode: 494, Ep Step: 200, Raw Reward: -115.41, Epsilon: 0.63
# Episode: 495, Ep Step: 200, Raw Reward: -114.87, Epsilon: 0.63
# Episode: 496, Ep Step: 200, Raw Reward: -110.14, Epsilon: 0.63
# Episode: 497, Ep Step: 200, Raw Reward: -117.33, Epsilon: 0.63
# Episode: 498, Ep Step: 200, Raw Reward: -113.57, Epsilon: 0.63
# Episode: 499, Ep Step: 200, Raw Reward: -112.30, Epsilon: 0.63
# Model saved
#
# Episode: 500, Ep Step: 200, Raw Reward: -117.68, Epsilon: 0.63
# Episode: 501, Ep Step: 200, Raw Reward: -105.33, Epsilon: 0.62
# Episode: 502, Ep Step: 200, Raw Reward: -113.59, Epsilon: 0.62
# Episode: 503, Ep Step: 200, Raw Reward: -120.50, Epsilon: 0.62
# Episode: 504, Ep Step: 200, Raw Reward: -107.97, Epsilon: 0.62
# Episode: 505, Ep Step: 200, Raw Reward: -113.58, Epsilon: 0.62
# Episode: 506, Ep Step: 200, Raw Reward: -117.13, Epsilon: 0.62
# Episode: 507, Ep Step: 200, Raw Reward: -119.51, Epsilon: 0.62
# Episode: 508, Ep Step: 200, Raw Reward: -113.46, Epsilon: 0.62
# Episode: 509, Ep Step: 200, Raw Reward: -116.51, Epsilon: 0.62
# Episode: 510, Ep Step: 200, Raw Reward: -115.77, Epsilon: 0.62
# Episode: 511, Ep Step: 200, Raw Reward: -118.14, Epsilon: 0.62
# Episode: 512, Ep Step: 200, Raw Reward: -113.24, Epsilon: 0.62
# Episode: 513, Ep Step: 200, Raw Reward: -112.59, Epsilon: 0.62
# Episode: 514, Ep Step: 200, Raw Reward: -114.03, Epsilon: 0.62
# Episode: 515, Ep Step: 200, Raw Reward: -116.12, Epsilon: 0.62
# Episode: 516, Ep Step: 200, Raw Reward: -118.76, Epsilon: 0.62
# Episode: 517, Ep Step: 200, Raw Reward: -119.06, Epsilon: 0.62
# Episode: 518, Ep Step: 200, Raw Reward: -116.80, Epsilon: 0.62
# Episode: 519, Ep Step: 200, Raw Reward: -114.49, Epsilon: 0.61
# Episode: 520, Ep Step: 200, Raw Reward: -112.73, Epsilon: 0.61
# Episode: 521, Ep Step: 200, Raw Reward: -117.72, Epsilon: 0.61
# Episode: 522, Ep Step: 200, Raw Reward: -114.40, Epsilon: 0.61
# Episode: 523, Ep Step: 200, Raw Reward: -110.02, Epsilon: 0.61
# Episode: 524, Ep Step: 200, Raw Reward: -119.97, Epsilon: 0.61
# Episode: 525, Ep Step: 200, Raw Reward: -116.39, Epsilon: 0.61
# Episode: 526, Ep Step: 200, Raw Reward: -109.16, Epsilon: 0.61
# Episode: 527, Ep Step: 200, Raw Reward: -112.62, Epsilon: 0.61
# Episode: 528, Ep Step: 200, Raw Reward: -115.12, Epsilon: 0.61
# Episode: 529, Ep Step: 200, Raw Reward: -114.38, Epsilon: 0.61
# Episode: 530, Ep Step: 200, Raw Reward: -113.75, Epsilon: 0.61
# Episode: 531, Ep Step: 200, Raw Reward: -112.84, Epsilon: 0.61
# Episode: 532, Ep Step: 200, Raw Reward: -110.77, Epsilon: 0.61
# Episode: 533, Ep Step: 200, Raw Reward: -119.99, Epsilon: 0.61
# Episode: 534, Ep Step: 200, Raw Reward: -115.61, Epsilon: 0.61
# Episode: 535, Ep Step: 200, Raw Reward: -113.47, Epsilon: 0.61
# Episode: 536, Ep Step: 200, Raw Reward: -116.01, Epsilon: 0.61
# Episode: 537, Ep Step: 200, Raw Reward: -118.21, Epsilon: 0.60
# Episode: 538, Ep Step: 200, Raw Reward: -112.47, Epsilon: 0.60
# Episode: 539, Ep Step: 200, Raw Reward: -117.72, Epsilon: 0.60
# Episode: 540, Ep Step: 200, Raw Reward: -112.62, Epsilon: 0.60
# Episode: 541, Ep Step: 200, Raw Reward: -115.19, Epsilon: 0.60
# Episode: 542, Ep Step: 200, Raw Reward: -113.55, Epsilon: 0.60
# Episode: 543, Ep Step: 200, Raw Reward: -120.80, Epsilon: 0.60
# Episode: 544, Ep Step: 200, Raw Reward: -113.57, Epsilon: 0.60
# Episode: 545, Ep Step: 200, Raw Reward: -106.81, Epsilon: 0.60
# Episode: 546, Ep Step: 200, Raw Reward: -117.10, Epsilon: 0.60
# Episode: 547, Ep Step: 200, Raw Reward: -116.38, Epsilon: 0.60
# Episode: 548, Ep Step: 200, Raw Reward: -114.91, Epsilon: 0.60
# Episode: 549, Ep Step: 200, Raw Reward: -113.36, Epsilon: 0.60
# Episode: 550, Ep Step: 200, Raw Reward: -107.63, Epsilon: 0.60
# Episode: 551, Ep Step: 200, Raw Reward: -114.62, Epsilon: 0.60
# Episode: 552, Ep Step: 200, Raw Reward: -117.12, Epsilon: 0.60
# Episode: 553, Ep Step: 200, Raw Reward: -114.87, Epsilon: 0.60
# Episode: 554, Ep Step: 200, Raw Reward: -118.64, Epsilon: 0.60
# Episode: 555, Ep Step: 200, Raw Reward: -112.00, Epsilon: 0.59
# Episode: 556, Ep Step: 200, Raw Reward: -112.62, Epsilon: 0.59
# Episode: 557, Ep Step: 200, Raw Reward: -116.92, Epsilon: 0.59
# Episode: 558, Ep Step: 200, Raw Reward: -118.55, Epsilon: 0.59
# Episode: 559, Ep Step: 200, Raw Reward: -117.39, Epsilon: 0.59
# Episode: 560, Ep Step: 200, Raw Reward: -112.45, Epsilon: 0.59
# Episode: 561, Ep Step: 200, Raw Reward: -113.85, Epsilon: 0.59
# Episode: 562, Ep Step: 200, Raw Reward: -111.33, Epsilon: 0.59
# Episode: 563, Ep Step: 200, Raw Reward: -119.65, Epsilon: 0.59
# Episode: 564, Ep Step: 200, Raw Reward: -106.55, Epsilon: 0.59
# Episode: 565, Ep Step: 200, Raw Reward: -114.45, Epsilon: 0.59
# Episode: 566, Ep Step: 200, Raw Reward: -117.74, Epsilon: 0.59
# Episode: 567, Ep Step: 200, Raw Reward: -117.12, Epsilon: 0.59
# Episode: 568, Ep Step: 200, Raw Reward: -116.74, Epsilon: 0.59
# Episode: 569, Ep Step: 200, Raw Reward: -113.84, Epsilon: 0.59
# Episode: 570, Ep Step: 200, Raw Reward: -109.64, Epsilon: 0.59
# Episode: 571, Ep Step: 200, Raw Reward: -113.19, Epsilon: 0.59
# Episode: 572, Ep Step: 200, Raw Reward: -113.40, Epsilon: 0.59
# Episode: 573, Ep Step: 200, Raw Reward: -118.63, Epsilon: 0.58
# Episode: 574, Ep Step: 200, Raw Reward: -110.98, Epsilon: 0.58
# Episode: 575, Ep Step: 200, Raw Reward: -116.16, Epsilon: 0.58
# Episode: 576, Ep Step: 200, Raw Reward: -114.45, Epsilon: 0.58
# Episode: 577, Ep Step: 200, Raw Reward: -112.43, Epsilon: 0.58
# Episode: 578, Ep Step: 200, Raw Reward: -114.68, Epsilon: 0.58
# Episode: 579, Ep Step: 200, Raw Reward: -119.14, Epsilon: 0.58
# Episode: 580, Ep Step: 200, Raw Reward: -110.99, Epsilon: 0.58
# Episode: 581, Ep Step: 200, Raw Reward: -119.77, Epsilon: 0.58
# Episode: 582, Ep Step: 200, Raw Reward: -114.22, Epsilon: 0.58
# Episode: 583, Ep Step: 200, Raw Reward: -117.88, Epsilon: 0.58
# Episode: 584, Ep Step: 200, Raw Reward: -113.92, Epsilon: 0.58
# Episode: 585, Ep Step: 200, Raw Reward: -111.46, Epsilon: 0.58
# Episode: 586, Ep Step: 200, Raw Reward: -118.29, Epsilon: 0.58
# Episode: 587, Ep Step: 200, Raw Reward: -114.17, Epsilon: 0.58
# Episode: 588, Ep Step: 200, Raw Reward: -109.50, Epsilon: 0.58
# Episode: 589, Ep Step: 200, Raw Reward: -110.55, Epsilon: 0.58
# Episode: 590, Ep Step: 200, Raw Reward: -116.26, Epsilon: 0.58
# Episode: 591, Ep Step: 200, Raw Reward: -114.52, Epsilon: 0.58
# Episode: 592, Ep Step: 200, Raw Reward: -116.88, Epsilon: 0.57
# Episode: 593, Ep Step: 200, Raw Reward: -112.04, Epsilon: 0.57
# Episode: 594, Ep Step: 200, Raw Reward: -113.01, Epsilon: 0.57
# Episode: 595, Ep Step: 200, Raw Reward: -109.77, Epsilon: 0.57
# Episode: 596, Ep Step: 200, Raw Reward: -114.55, Epsilon: 0.57
# Episode: 597, Ep Step: 200, Raw Reward: -109.35, Epsilon: 0.57
# Episode: 598, Ep Step: 200, Raw Reward: -112.57, Epsilon: 0.57
# Episode: 599, Ep Step: 200, Raw Reward: -114.30, Epsilon: 0.57
# Episode: 600, Ep Step: 200, Raw Reward: -116.47, Epsilon: 0.57
# Episode: 601, Ep Step: 200, Raw Reward: -120.71, Epsilon: 0.57
# Episode: 602, Ep Step: 200, Raw Reward: -119.87, Epsilon: 0.57
# Episode: 603, Ep Step: 200, Raw Reward: -117.11, Epsilon: 0.57
# Episode: 604, Ep Step: 200, Raw Reward: -112.03, Epsilon: 0.57
# Episode: 605, Ep Step: 200, Raw Reward: -110.06, Epsilon: 0.57
# Episode: 606, Ep Step: 200, Raw Reward: -112.41, Epsilon: 0.57
# Episode: 607, Ep Step: 200, Raw Reward: -119.04, Epsilon: 0.57
# Episode: 608, Ep Step: 200, Raw Reward: -118.81, Epsilon: 0.57
# Episode: 609, Ep Step: 200, Raw Reward: -119.08, Epsilon: 0.57
# Episode: 610, Ep Step: 200, Raw Reward: -111.31, Epsilon: 0.57
# Episode: 611, Ep Step: 200, Raw Reward: -109.25, Epsilon: 0.56
# Episode: 612, Ep Step: 200, Raw Reward: -113.21, Epsilon: 0.56
# Episode: 613, Ep Step: 200, Raw Reward: -111.24, Epsilon: 0.56
# Episode: 614, Ep Step: 200, Raw Reward: -112.21, Epsilon: 0.56
# Episode: 615, Ep Step: 200, Raw Reward: -105.82, Epsilon: 0.56
# Episode: 616, Ep Step: 200, Raw Reward: -114.27, Epsilon: 0.56
# Episode: 617, Ep Step: 200, Raw Reward: -116.46, Epsilon: 0.56
# Episode: 618, Ep Step: 200, Raw Reward: -106.79, Epsilon: 0.56
# Episode: 619, Ep Step: 200, Raw Reward: -113.03, Epsilon: 0.56
# Episode: 620, Ep Step: 200, Raw Reward: -110.25, Epsilon: 0.56
# Episode: 621, Ep Step: 200, Raw Reward: -117.75, Epsilon: 0.56
# Episode: 622, Ep Step: 200, Raw Reward: -115.41, Epsilon: 0.56
# Episode: 623, Ep Step: 200, Raw Reward: -112.87, Epsilon: 0.56
# Episode: 624, Ep Step: 200, Raw Reward: -99.73, Epsilon: 0.56
# Episode: 625, Ep Step: 200, Raw Reward: -116.92, Epsilon: 0.56
# Episode: 626, Ep Step: 200, Raw Reward: -111.49, Epsilon: 0.56
# Episode: 627, Ep Step: 200, Raw Reward: -110.71, Epsilon: 0.56
# Episode: 628, Ep Step: 200, Raw Reward: -117.53, Epsilon: 0.56
# Episode: 629, Ep Step: 200, Raw Reward: -114.62, Epsilon: 0.56
# Episode: 630, Ep Step: 200, Raw Reward: -112.54, Epsilon: 0.56
# Episode: 631, Ep Step: 200, Raw Reward: -117.18, Epsilon: 0.55
# Episode: 632, Ep Step: 200, Raw Reward: -117.47, Epsilon: 0.55
# Episode: 633, Ep Step: 200, Raw Reward: -115.18, Epsilon: 0.55
# Episode: 634, Ep Step: 200, Raw Reward: -113.20, Epsilon: 0.55
# Episode: 635, Ep Step: 200, Raw Reward: -116.15, Epsilon: 0.55
# Episode: 636, Ep Step: 200, Raw Reward: -106.04, Epsilon: 0.55
# Episode: 637, Ep Step: 200, Raw Reward: -111.24, Epsilon: 0.55
# Episode: 638, Ep Step: 200, Raw Reward: -120.71, Epsilon: 0.55
# Episode: 639, Ep Step: 200, Raw Reward: -112.52, Epsilon: 0.55
# Episode: 640, Ep Step: 200, Raw Reward: -113.03, Epsilon: 0.55
# Episode: 641, Ep Step: 200, Raw Reward: -116.32, Epsilon: 0.55
# Episode: 642, Ep Step: 200, Raw Reward: -109.28, Epsilon: 0.55
# Episode: 643, Ep Step: 200, Raw Reward: -118.37, Epsilon: 0.55
# Episode: 644, Ep Step: 200, Raw Reward: -114.48, Epsilon: 0.55
# Episode: 645, Ep Step: 200, Raw Reward: -109.12, Epsilon: 0.55
# Episode: 646, Ep Step: 200, Raw Reward: -109.88, Epsilon: 0.55
# Episode: 647, Ep Step: 200, Raw Reward: -114.87, Epsilon: 0.55
# Episode: 648, Ep Step: 200, Raw Reward: -113.66, Epsilon: 0.55
# Episode: 649, Ep Step: 200, Raw Reward: -114.09, Epsilon: 0.55
# Episode: 650, Ep Step: 200, Raw Reward: -117.26, Epsilon: 0.55
# Episode: 651, Ep Step: 200, Raw Reward: -105.73, Epsilon: 0.54
# Episode: 652, Ep Step: 200, Raw Reward: -112.54, Epsilon: 0.54
# Episode: 653, Ep Step: 200, Raw Reward: -114.89, Epsilon: 0.54
# Episode: 654, Ep Step: 200, Raw Reward: -116.32, Epsilon: 0.54
# Episode: 655, Ep Step: 200, Raw Reward: -109.13, Epsilon: 0.54
# Episode: 656, Ep Step: 200, Raw Reward: -113.51, Epsilon: 0.54
# Episode: 657, Ep Step: 200, Raw Reward: -117.80, Epsilon: 0.54
# Episode: 658, Ep Step: 200, Raw Reward: -114.20, Epsilon: 0.54
# Episode: 659, Ep Step: 200, Raw Reward: -112.84, Epsilon: 0.54
# Episode: 660, Ep Step: 200, Raw Reward: -115.03, Epsilon: 0.54
# Episode: 661, Ep Step: 200, Raw Reward: -117.07, Epsilon: 0.54
# Episode: 662, Ep Step: 200, Raw Reward: -111.60, Epsilon: 0.54
# Episode: 663, Ep Step: 200, Raw Reward: -112.41, Epsilon: 0.54
# Episode: 664, Ep Step: 200, Raw Reward: -112.85, Epsilon: 0.54
# Episode: 665, Ep Step: 200, Raw Reward: -109.14, Epsilon: 0.54
# Episode: 666, Ep Step: 200, Raw Reward: -114.98, Epsilon: 0.54
# Episode: 667, Ep Step: 200, Raw Reward: -117.18, Epsilon: 0.54
# Episode: 668, Ep Step: 200, Raw Reward: -110.45, Epsilon: 0.54
# Episode: 669, Ep Step: 200, Raw Reward: -109.87, Epsilon: 0.54
# Episode: 670, Ep Step: 200, Raw Reward: -108.78, Epsilon: 0.54
# Episode: 671, Ep Step: 200, Raw Reward: -111.88, Epsilon: 0.53
# Episode: 672, Ep Step: 200, Raw Reward: -109.35, Epsilon: 0.53
# Episode: 673, Ep Step: 200, Raw Reward: -112.42, Epsilon: 0.53
# Episode: 674, Ep Step: 200, Raw Reward: -114.62, Epsilon: 0.53
# Episode: 675, Ep Step: 200, Raw Reward: -112.00, Epsilon: 0.53
# Episode: 676, Ep Step: 200, Raw Reward: -112.14, Epsilon: 0.53
# Episode: 677, Ep Step: 200, Raw Reward: -111.62, Epsilon: 0.53
# Episode: 678, Ep Step: 200, Raw Reward: -113.75, Epsilon: 0.53
# Episode: 679, Ep Step: 200, Raw Reward: -111.89, Epsilon: 0.53
# Episode: 680, Ep Step: 200, Raw Reward: -113.34, Epsilon: 0.53
# Episode: 681, Ep Step: 200, Raw Reward: -118.48, Epsilon: 0.53
# Episode: 682, Ep Step: 200, Raw Reward: -111.31, Epsilon: 0.53
# Episode: 683, Ep Step: 200, Raw Reward: -108.41, Epsilon: 0.53
# Episode: 684, Ep Step: 200, Raw Reward: -110.90, Epsilon: 0.53
# Episode: 685, Ep Step: 200, Raw Reward: -110.84, Epsilon: 0.53
# Episode: 686, Ep Step: 200, Raw Reward: -115.43, Epsilon: 0.53
# Episode: 687, Ep Step: 200, Raw Reward: -111.42, Epsilon: 0.53
# Episode: 688, Ep Step: 200, Raw Reward: -113.99, Epsilon: 0.53
# Episode: 689, Ep Step: 200, Raw Reward: -109.93, Epsilon: 0.53
# Episode: 690, Ep Step: 200, Raw Reward: -104.79, Epsilon: 0.53
# Episode: 691, Ep Step: 200, Raw Reward: -114.05, Epsilon: 0.53
# Episode: 692, Ep Step: 200, Raw Reward: -112.85, Epsilon: 0.52
# Episode: 693, Ep Step: 200, Raw Reward: -117.17, Epsilon: 0.52
# Episode: 694, Ep Step: 200, Raw Reward: -118.09, Epsilon: 0.52
# Episode: 695, Ep Step: 200, Raw Reward: -111.27, Epsilon: 0.52
# Episode: 696, Ep Step: 200, Raw Reward: -113.40, Epsilon: 0.52
# Episode: 697, Ep Step: 200, Raw Reward: -111.05, Epsilon: 0.52
# Episode: 698, Ep Step: 200, Raw Reward: -110.43, Epsilon: 0.52
# Episode: 699, Ep Step: 200, Raw Reward: -106.70, Epsilon: 0.52
# Episode: 700, Ep Step: 200, Raw Reward: -118.34, Epsilon: 0.52
# Episode: 701, Ep Step: 200, Raw Reward: -115.20, Epsilon: 0.52
# Episode: 702, Ep Step: 200, Raw Reward: -109.88, Epsilon: 0.52
# Episode: 703, Ep Step: 200, Raw Reward: -114.91, Epsilon: 0.52
# Episode: 704, Ep Step: 200, Raw Reward: -116.56, Epsilon: 0.52
# Episode: 705, Ep Step: 200, Raw Reward: -111.67, Epsilon: 0.52
# Episode: 706, Ep Step: 200, Raw Reward: -107.17, Epsilon: 0.52
# Episode: 707, Ep Step: 200, Raw Reward: -114.83, Epsilon: 0.52
# Episode: 708, Ep Step: 200, Raw Reward: -111.11, Epsilon: 0.52
# Episode: 709, Ep Step: 200, Raw Reward: -116.78, Epsilon: 0.52
# Episode: 710, Ep Step: 200, Raw Reward: -109.78, Epsilon: 0.52
# Episode: 711, Ep Step: 200, Raw Reward: -110.96, Epsilon: 0.52
# Episode: 712, Ep Step: 200, Raw Reward: -112.14, Epsilon: 0.52
# Episode: 713, Ep Step: 200, Raw Reward: -110.18, Epsilon: 0.52
# Episode: 714, Ep Step: 200, Raw Reward: -112.01, Epsilon: 0.51
# Episode: 715, Ep Step: 200, Raw Reward: -104.34, Epsilon: 0.51
# Episode: 716, Ep Step: 200, Raw Reward: -112.14, Epsilon: 0.51
# Episode: 717, Ep Step: 200, Raw Reward: -112.14, Epsilon: 0.51
# Episode: 718, Ep Step: 200, Raw Reward: -109.05, Epsilon: 0.51
# Episode: 719, Ep Step: 200, Raw Reward: -111.38, Epsilon: 0.51
# Episode: 720, Ep Step: 200, Raw Reward: -107.68, Epsilon: 0.51
# Episode: 721, Ep Step: 200, Raw Reward: -115.05, Epsilon: 0.51
# Episode: 722, Ep Step: 200, Raw Reward: -109.22, Epsilon: 0.51
# Episode: 723, Ep Step: 200, Raw Reward: -114.46, Epsilon: 0.51
# Episode: 724, Ep Step: 200, Raw Reward: -114.36, Epsilon: 0.51
# Episode: 725, Ep Step: 200, Raw Reward: -111.90, Epsilon: 0.51
# Episode: 726, Ep Step: 200, Raw Reward: -112.47, Epsilon: 0.51
# Episode: 727, Ep Step: 200, Raw Reward: -114.36, Epsilon: 0.51
# Episode: 728, Ep Step: 200, Raw Reward: -113.35, Epsilon: 0.51
# Episode: 729, Ep Step: 200, Raw Reward: -106.24, Epsilon: 0.51
# Episode: 730, Ep Step: 200, Raw Reward: -107.68, Epsilon: 0.51
# Episode: 731, Ep Step: 200, Raw Reward: -111.71, Epsilon: 0.51
# Episode: 732, Ep Step: 200, Raw Reward: -110.41, Epsilon: 0.51
# Episode: 733, Ep Step: 200, Raw Reward: -115.62, Epsilon: 0.51
# Episode: 734, Ep Step: 200, Raw Reward: -113.56, Epsilon: 0.51
# Episode: 735, Ep Step: 200, Raw Reward: -107.77, Epsilon: 0.50
# Episode: 736, Ep Step: 200, Raw Reward: -117.51, Epsilon: 0.50
# Episode: 737, Ep Step: 200, Raw Reward: -115.79, Epsilon: 0.50
# Episode: 738, Ep Step: 200, Raw Reward: -105.62, Epsilon: 0.50
# Episode: 739, Ep Step: 200, Raw Reward: -108.61, Epsilon: 0.50
# Episode: 740, Ep Step: 200, Raw Reward: -111.09, Epsilon: 0.50
# Episode: 741, Ep Step: 200, Raw Reward: -111.79, Epsilon: 0.50
# Episode: 742, Ep Step: 200, Raw Reward: -118.86, Epsilon: 0.50
# Episode: 743, Ep Step: 200, Raw Reward: -116.79, Epsilon: 0.50
# Episode: 744, Ep Step: 200, Raw Reward: -106.48, Epsilon: 0.50
# Episode: 745, Ep Step: 200, Raw Reward: -118.65, Epsilon: 0.50
# Episode: 746, Ep Step: 200, Raw Reward: -111.20, Epsilon: 0.50
# Episode: 747, Ep Step: 200, Raw Reward: -113.97, Epsilon: 0.50
# Episode: 748, Ep Step: 200, Raw Reward: -114.87, Epsilon: 0.50
# Episode: 749, Ep Step: 200, Raw Reward: -104.03, Epsilon: 0.50
# Episode: 750, Ep Step: 200, Raw Reward: -108.96, Epsilon: 0.50
# Episode: 751, Ep Step: 200, Raw Reward: -106.19, Epsilon: 0.50
# Episode: 752, Ep Step: 200, Raw Reward: -116.13, Epsilon: 0.50
# Episode: 753, Ep Step: 200, Raw Reward: -117.75, Epsilon: 0.50
# Episode: 754, Ep Step: 200, Raw Reward: -112.61, Epsilon: 0.50
# Episode: 755, Ep Step: 200, Raw Reward: -117.89, Epsilon: 0.50
# Episode: 756, Ep Step: 200, Raw Reward: -111.67, Epsilon: 0.50
# Episode: 757, Ep Step: 200, Raw Reward: -108.06, Epsilon: 0.49
# Episode: 758, Ep Step: 200, Raw Reward: -107.87, Epsilon: 0.49
# Episode: 759, Ep Step: 200, Raw Reward: -112.36, Epsilon: 0.49
# Episode: 760, Ep Step: 200, Raw Reward: -112.52, Epsilon: 0.49
# Episode: 761, Ep Step: 200, Raw Reward: -112.60, Epsilon: 0.49
# Episode: 762, Ep Step: 200, Raw Reward: -118.57, Epsilon: 0.49
# Episode: 763, Ep Step: 200, Raw Reward: -115.15, Epsilon: 0.49
# Episode: 764, Ep Step: 200, Raw Reward: -112.25, Epsilon: 0.49
# Episode: 765, Ep Step: 200, Raw Reward: -107.33, Epsilon: 0.49
# Episode: 766, Ep Step: 200, Raw Reward: -115.78, Epsilon: 0.49
# Episode: 767, Ep Step: 200, Raw Reward: -112.54, Epsilon: 0.49
# Episode: 768, Ep Step: 200, Raw Reward: -111.76, Epsilon: 0.49
# Episode: 769, Ep Step: 200, Raw Reward: -115.43, Epsilon: 0.49
# Episode: 770, Ep Step: 200, Raw Reward: -117.32, Epsilon: 0.49
# Episode: 771, Ep Step: 200, Raw Reward: -112.76, Epsilon: 0.49
# Episode: 772, Ep Step: 200, Raw Reward: -111.75, Epsilon: 0.49
# Episode: 773, Ep Step: 200, Raw Reward: -112.53, Epsilon: 0.49
# Episode: 774, Ep Step: 200, Raw Reward: -105.21, Epsilon: 0.49
# Episode: 775, Ep Step: 200, Raw Reward: -115.54, Epsilon: 0.49
# Episode: 776, Ep Step: 200, Raw Reward: -110.80, Epsilon: 0.49
# Episode: 777, Ep Step: 200, Raw Reward: -110.53, Epsilon: 0.49
# Episode: 778, Ep Step: 200, Raw Reward: -109.46, Epsilon: 0.49
# Episode: 779, Ep Step: 200, Raw Reward: -110.66, Epsilon: 0.49
# Episode: 780, Ep Step: 200, Raw Reward: -108.88, Epsilon: 0.48
# Episode: 781, Ep Step: 200, Raw Reward: -112.59, Epsilon: 0.48
# Episode: 782, Ep Step: 200, Raw Reward: -111.26, Epsilon: 0.48
# Episode: 783, Ep Step: 200, Raw Reward: -112.46, Epsilon: 0.48
# Episode: 784, Ep Step: 200, Raw Reward: -116.00, Epsilon: 0.48
# Episode: 785, Ep Step: 200, Raw Reward: -104.11, Epsilon: 0.48
# Episode: 786, Ep Step: 200, Raw Reward: -107.33, Epsilon: 0.48
# Episode: 787, Ep Step: 200, Raw Reward: -112.65, Epsilon: 0.48
# Episode: 788, Ep Step: 200, Raw Reward: -108.33, Epsilon: 0.48
# Episode: 789, Ep Step: 200, Raw Reward: -118.03, Epsilon: 0.48
# Episode: 790, Ep Step: 200, Raw Reward: -113.48, Epsilon: 0.48
# Episode: 791, Ep Step: 200, Raw Reward: -116.90, Epsilon: 0.48
# Episode: 792, Ep Step: 200, Raw Reward: -110.61, Epsilon: 0.48
# Episode: 793, Ep Step: 200, Raw Reward: -111.88, Epsilon: 0.48
# Episode: 794, Ep Step: 200, Raw Reward: -112.88, Epsilon: 0.48
# Episode: 795, Ep Step: 200, Raw Reward: -113.69, Epsilon: 0.48
# Episode: 796, Ep Step: 200, Raw Reward: -110.87, Epsilon: 0.48
# Episode: 797, Ep Step: 200, Raw Reward: -112.40, Epsilon: 0.48
# Episode: 798, Ep Step: 200, Raw Reward: -111.85, Epsilon: 0.48
# Episode: 799, Ep Step: 200, Raw Reward: -116.48, Epsilon: 0.48
# Episode: 800, Ep Step: 200, Raw Reward: -105.90, Epsilon: 0.48
# Episode: 801, Ep Step: 200, Raw Reward: -112.92, Epsilon: 0.48
# Episode: 802, Ep Step: 200, Raw Reward: -108.34, Epsilon: 0.48
# Episode: 803, Ep Step: 200, Raw Reward: -115.59, Epsilon: 0.47
# Episode: 804, Ep Step: 200, Raw Reward: -106.49, Epsilon: 0.47
# Episode: 805, Ep Step: 200, Raw Reward: -117.23, Epsilon: 0.47
# Episode: 806, Ep Step: 200, Raw Reward: -118.38, Epsilon: 0.47
# Episode: 807, Ep Step: 200, Raw Reward: -113.80, Epsilon: 0.47
# Episode: 808, Ep Step: 200, Raw Reward: -112.82, Epsilon: 0.47
# Episode: 809, Ep Step: 200, Raw Reward: -112.63, Epsilon: 0.47
# Episode: 810, Ep Step: 200, Raw Reward: -106.41, Epsilon: 0.47
# Episode: 811, Ep Step: 200, Raw Reward: -118.20, Epsilon: 0.47
# Episode: 812, Ep Step: 200, Raw Reward: -103.54, Epsilon: 0.47
# Episode: 813, Ep Step: 200, Raw Reward: -111.89, Epsilon: 0.47
# Episode: 814, Ep Step: 200, Raw Reward: -113.84, Epsilon: 0.47
# Episode: 815, Ep Step: 200, Raw Reward: -111.65, Epsilon: 0.47
# Episode: 816, Ep Step: 200, Raw Reward: -111.29, Epsilon: 0.47
# Episode: 817, Ep Step: 200, Raw Reward: -113.30, Epsilon: 0.47
# Episode: 818, Ep Step: 200, Raw Reward: -109.38, Epsilon: 0.47
# Episode: 819, Ep Step: 200, Raw Reward: -109.17, Epsilon: 0.47
# Episode: 820, Ep Step: 200, Raw Reward: -113.92, Epsilon: 0.47
# Episode: 821, Ep Step: 200, Raw Reward: -113.43, Epsilon: 0.47
# Episode: 822, Ep Step: 200, Raw Reward: -114.56, Epsilon: 0.47
# Episode: 823, Ep Step: 200, Raw Reward: -121.58, Epsilon: 0.47
# Episode: 824, Ep Step: 200, Raw Reward: -114.74, Epsilon: 0.47
# Episode: 825, Ep Step: 200, Raw Reward: -115.31, Epsilon: 0.47
# Episode: 826, Ep Step: 200, Raw Reward: -107.03, Epsilon: 0.47
# Episode: 827, Ep Step: 200, Raw Reward: -111.29, Epsilon: 0.46
# Episode: 828, Ep Step: 200, Raw Reward: -110.04, Epsilon: 0.46
# Episode: 829, Ep Step: 200, Raw Reward: -113.94, Epsilon: 0.46
# Episode: 830, Ep Step: 200, Raw Reward: -113.48, Epsilon: 0.46
# Episode: 831, Ep Step: 200, Raw Reward: -114.10, Epsilon: 0.46
# Episode: 832, Ep Step: 200, Raw Reward: -111.61, Epsilon: 0.46
# Episode: 833, Ep Step: 200, Raw Reward: -113.89, Epsilon: 0.46
# Episode: 834, Ep Step: 200, Raw Reward: -115.93, Epsilon: 0.46
# Episode: 835, Ep Step: 200, Raw Reward: -112.08, Epsilon: 0.46
# Episode: 836, Ep Step: 200, Raw Reward: -110.53, Epsilon: 0.46
# Episode: 837, Ep Step: 200, Raw Reward: -108.72, Epsilon: 0.46
# Episode: 838, Ep Step: 200, Raw Reward: -110.42, Epsilon: 0.46
# Episode: 839, Ep Step: 200, Raw Reward: -110.72, Epsilon: 0.46
# Episode: 840, Ep Step: 200, Raw Reward: -113.99, Epsilon: 0.46
# Episode: 841, Ep Step: 200, Raw Reward: -112.71, Epsilon: 0.46
# Episode: 842, Ep Step: 200, Raw Reward: -113.90, Epsilon: 0.46
# Episode: 843, Ep Step: 200, Raw Reward: -112.74, Epsilon: 0.46
# Episode: 844, Ep Step: 200, Raw Reward: -114.64, Epsilon: 0.46
# Episode: 845, Ep Step: 200, Raw Reward: -112.35, Epsilon: 0.46
# Episode: 846, Ep Step: 200, Raw Reward: -115.24, Epsilon: 0.46
# Episode: 847, Ep Step: 200, Raw Reward: -114.14, Epsilon: 0.46
# Episode: 848, Ep Step: 200, Raw Reward: -113.47, Epsilon: 0.46
# Episode: 849, Ep Step: 200, Raw Reward: -103.17, Epsilon: 0.46
# Episode: 850, Ep Step: 200, Raw Reward: -109.20, Epsilon: 0.46
# Episode: 851, Ep Step: 200, Raw Reward: -109.58, Epsilon: 0.46
# Episode: 852, Ep Step: 200, Raw Reward: -114.80, Epsilon: 0.45
# Episode: 853, Ep Step: 200, Raw Reward: -112.65, Epsilon: 0.45
# Episode: 854, Ep Step: 200, Raw Reward: -118.83, Epsilon: 0.45
# Episode: 855, Ep Step: 200, Raw Reward: -114.12, Epsilon: 0.45
# Episode: 856, Ep Step: 200, Raw Reward: -113.98, Epsilon: 0.45
# Episode: 857, Ep Step: 200, Raw Reward: -113.02, Epsilon: 0.45
# Episode: 858, Ep Step: 200, Raw Reward: -108.13, Epsilon: 0.45
# Episode: 859, Ep Step: 200, Raw Reward: -111.84, Epsilon: 0.45
# Episode: 860, Ep Step: 200, Raw Reward: -112.65, Epsilon: 0.45
# Episode: 861, Ep Step: 200, Raw Reward: -110.14, Epsilon: 0.45
# Episode: 862, Ep Step: 200, Raw Reward: -113.86, Epsilon: 0.45
# Episode: 863, Ep Step: 200, Raw Reward: -116.56, Epsilon: 0.45
# Episode: 864, Ep Step: 200, Raw Reward: -114.15, Epsilon: 0.45
# Episode: 865, Ep Step: 200, Raw Reward: -112.74, Epsilon: 0.45
# Episode: 866, Ep Step: 200, Raw Reward: -114.42, Epsilon: 0.45
# Episode: 867, Ep Step: 200, Raw Reward: -115.80, Epsilon: 0.45
# Episode: 868, Ep Step: 200, Raw Reward: -113.86, Epsilon: 0.45
# Episode: 869, Ep Step: 200, Raw Reward: -113.53, Epsilon: 0.45
# Episode: 870, Ep Step: 200, Raw Reward: -116.94, Epsilon: 0.45
# Episode: 871, Ep Step: 200, Raw Reward: -106.87, Epsilon: 0.45
# Episode: 872, Ep Step: 200, Raw Reward: -117.45, Epsilon: 0.45
# Episode: 873, Ep Step: 200, Raw Reward: -105.84, Epsilon: 0.45
# Episode: 874, Ep Step: 200, Raw Reward: -111.27, Epsilon: 0.45
# Episode: 875, Ep Step: 200, Raw Reward: -116.55, Epsilon: 0.45
# Episode: 876, Ep Step: 200, Raw Reward: -112.42, Epsilon: 0.45
# Episode: 877, Ep Step: 200, Raw Reward: -114.72, Epsilon: 0.44
# Episode: 878, Ep Step: 200, Raw Reward: -112.08, Epsilon: 0.44
# Episode: 879, Ep Step: 200, Raw Reward: -112.53, Epsilon: 0.44
# Episode: 880, Ep Step: 200, Raw Reward: -118.04, Epsilon: 0.44
# Episode: 881, Ep Step: 200, Raw Reward: -107.17, Epsilon: 0.44
# Episode: 882, Ep Step: 200, Raw Reward: -109.42, Epsilon: 0.44
# Episode: 883, Ep Step: 200, Raw Reward: -115.66, Epsilon: 0.44
# Episode: 884, Ep Step: 200, Raw Reward: -110.92, Epsilon: 0.44
# Episode: 885, Ep Step: 200, Raw Reward: -115.32, Epsilon: 0.44
# Episode: 886, Ep Step: 200, Raw Reward: -115.63, Epsilon: 0.44
# Episode: 887, Ep Step: 200, Raw Reward: -111.87, Epsilon: 0.44
# Episode: 888, Ep Step: 200, Raw Reward: -111.54, Epsilon: 0.44
# Episode: 889, Ep Step: 200, Raw Reward: -105.91, Epsilon: 0.44
# Episode: 890, Ep Step: 200, Raw Reward: -114.39, Epsilon: 0.44
# Episode: 891, Ep Step: 200, Raw Reward: -109.23, Epsilon: 0.44
# Episode: 892, Ep Step: 200, Raw Reward: -111.87, Epsilon: 0.44
# Episode: 893, Ep Step: 200, Raw Reward: -110.35, Epsilon: 0.44
# Episode: 894, Ep Step: 200, Raw Reward: -111.22, Epsilon: 0.44
# Episode: 895, Ep Step: 200, Raw Reward: -110.89, Epsilon: 0.44
# Episode: 896, Ep Step: 200, Raw Reward: -107.00, Epsilon: 0.44
# Episode: 897, Ep Step: 200, Raw Reward: -115.63, Epsilon: 0.44
# Episode: 898, Ep Step: 200, Raw Reward: -111.16, Epsilon: 0.44
# Episode: 899, Ep Step: 200, Raw Reward: -115.46, Epsilon: 0.44
# Episode: 900, Ep Step: 200, Raw Reward: -114.65, Epsilon: 0.44
# Episode: 901, Ep Step: 200, Raw Reward: -106.27, Epsilon: 0.44
# Episode: 902, Ep Step: 200, Raw Reward: -113.44, Epsilon: 0.43
# Episode: 903, Ep Step: 200, Raw Reward: -106.10, Epsilon: 0.43
# Episode: 904, Ep Step: 200, Raw Reward: -115.44, Epsilon: 0.43
# Episode: 905, Ep Step: 200, Raw Reward: -109.93, Epsilon: 0.43
# Episode: 906, Ep Step: 200, Raw Reward: -114.70, Epsilon: 0.43
# Episode: 907, Ep Step: 200, Raw Reward: -110.77, Epsilon: 0.43
# Episode: 908, Ep Step: 200, Raw Reward: -108.61, Epsilon: 0.43
# Episode: 909, Ep Step: 200, Raw Reward: -108.48, Epsilon: 0.43
# Episode: 910, Ep Step: 200, Raw Reward: -109.96, Epsilon: 0.43
# Episode: 911, Ep Step: 200, Raw Reward: -111.80, Epsilon: 0.43
# Episode: 912, Ep Step: 200, Raw Reward: -112.88, Epsilon: 0.43
# Episode: 913, Ep Step: 200, Raw Reward: -105.73, Epsilon: 0.43
# Episode: 914, Ep Step: 200, Raw Reward: -103.30, Epsilon: 0.43
# Episode: 915, Ep Step: 200, Raw Reward: -114.61, Epsilon: 0.43
# Episode: 916, Ep Step: 200, Raw Reward: -114.09, Epsilon: 0.43
# Episode: 917, Ep Step: 200, Raw Reward: -110.31, Epsilon: 0.43
# Episode: 918, Ep Step: 200, Raw Reward: -114.18, Epsilon: 0.43
# Episode: 919, Ep Step: 200, Raw Reward: -108.80, Epsilon: 0.43
# Episode: 920, Ep Step: 200, Raw Reward: -107.27, Epsilon: 0.43
# Episode: 921, Ep Step: 200, Raw Reward: -113.07, Epsilon: 0.43
# Episode: 922, Ep Step: 200, Raw Reward: -103.48, Epsilon: 0.43
# Episode: 923, Ep Step: 200, Raw Reward: -113.76, Epsilon: 0.43
# Episode: 924, Ep Step: 200, Raw Reward: -110.01, Epsilon: 0.43
# Episode: 925, Ep Step: 200, Raw Reward: -105.04, Epsilon: 0.43
# Episode: 926, Ep Step: 200, Raw Reward: -114.38, Epsilon: 0.43
# Episode: 927, Ep Step: 200, Raw Reward: -112.80, Epsilon: 0.43
# Episode: 928, Ep Step: 200, Raw Reward: -115.57, Epsilon: 0.43
# Episode: 929, Ep Step: 200, Raw Reward: -117.25, Epsilon: 0.42
# Episode: 930, Ep Step: 200, Raw Reward: -110.08, Epsilon: 0.42
# Episode: 931, Ep Step: 200, Raw Reward: -111.01, Epsilon: 0.42
# Episode: 932, Ep Step: 200, Raw Reward: -112.40, Epsilon: 0.42
# Episode: 933, Ep Step: 200, Raw Reward: -112.03, Epsilon: 0.42
# Episode: 934, Ep Step: 200, Raw Reward: -111.97, Epsilon: 0.42
# Episode: 935, Ep Step: 200, Raw Reward: -109.36, Epsilon: 0.42
# Episode: 936, Ep Step: 200, Raw Reward: -111.53, Epsilon: 0.42
# Episode: 937, Ep Step: 200, Raw Reward: -108.35, Epsilon: 0.42
# Episode: 938, Ep Step: 200, Raw Reward: -112.57, Epsilon: 0.42
# Episode: 939, Ep Step: 200, Raw Reward: -113.58, Epsilon: 0.42
# Episode: 940, Ep Step: 200, Raw Reward: -114.03, Epsilon: 0.42
# Episode: 941, Ep Step: 200, Raw Reward: -113.23, Epsilon: 0.42
# Episode: 942, Ep Step: 200, Raw Reward: -117.09, Epsilon: 0.42
# Episode: 943, Ep Step: 200, Raw Reward: -111.37, Epsilon: 0.42
# Episode: 944, Ep Step: 200, Raw Reward: -112.25, Epsilon: 0.42
# Episode: 945, Ep Step: 200, Raw Reward: -112.17, Epsilon: 0.42
# Episode: 946, Ep Step: 200, Raw Reward: -112.49, Epsilon: 0.42
# Episode: 947, Ep Step: 200, Raw Reward: -107.42, Epsilon: 0.42
# Episode: 948, Ep Step: 200, Raw Reward: -107.15, Epsilon: 0.42
# Episode: 949, Ep Step: 200, Raw Reward: -114.69, Epsilon: 0.42
# Episode: 950, Ep Step: 200, Raw Reward: -107.31, Epsilon: 0.42
# Episode: 951, Ep Step: 200, Raw Reward: -109.07, Epsilon: 0.42
# Episode: 952, Ep Step: 200, Raw Reward: -104.47, Epsilon: 0.42
# Episode: 953, Ep Step: 200, Raw Reward: -106.49, Epsilon: 0.42
# Episode: 954, Ep Step: 200, Raw Reward: -110.28, Epsilon: 0.42
# Episode: 955, Ep Step: 200, Raw Reward: -109.50, Epsilon: 0.42
# Episode: 956, Ep Step: 200, Raw Reward: -111.23, Epsilon: 0.41
# Episode: 957, Ep Step: 200, Raw Reward: -106.74, Epsilon: 0.41
# Episode: 958, Ep Step: 200, Raw Reward: -105.55, Epsilon: 0.41
# Episode: 959, Ep Step: 200, Raw Reward: -111.16, Epsilon: 0.41
# Episode: 960, Ep Step: 200, Raw Reward: -106.68, Epsilon: 0.41
# Episode: 961, Ep Step: 200, Raw Reward: -110.27, Epsilon: 0.41
# Episode: 962, Ep Step: 200, Raw Reward: -101.86, Epsilon: 0.41
# Episode: 963, Ep Step: 200, Raw Reward: -105.16, Epsilon: 0.41
# Episode: 964, Ep Step: 200, Raw Reward: -110.25, Epsilon: 0.41
# Episode: 965, Ep Step: 200, Raw Reward: -110.94, Epsilon: 0.41
# Episode: 966, Ep Step: 200, Raw Reward: -107.57, Epsilon: 0.41
# Episode: 967, Ep Step: 200, Raw Reward: -115.20, Epsilon: 0.41
# Episode: 968, Ep Step: 200, Raw Reward: -109.45, Epsilon: 0.41
# Episode: 969, Ep Step: 200, Raw Reward: -110.30, Epsilon: 0.41
# Episode: 970, Ep Step: 200, Raw Reward: -111.76, Epsilon: 0.41
# Episode: 971, Ep Step: 200, Raw Reward: -105.01, Epsilon: 0.41
# Episode: 972, Ep Step: 200, Raw Reward: -114.00, Epsilon: 0.41
# Episode: 973, Ep Step: 200, Raw Reward: -108.85, Epsilon: 0.41
# Episode: 974, Ep Step: 200, Raw Reward: -110.60, Epsilon: 0.41
# Episode: 975, Ep Step: 200, Raw Reward: -112.29, Epsilon: 0.41
# Episode: 976, Ep Step: 200, Raw Reward: -112.25, Epsilon: 0.41
# Episode: 977, Ep Step: 200, Raw Reward: -110.93, Epsilon: 0.41
# Episode: 978, Ep Step: 200, Raw Reward: -108.51, Epsilon: 0.41
# Episode: 979, Ep Step: 200, Raw Reward: -105.40, Epsilon: 0.41
# Episode: 980, Ep Step: 200, Raw Reward: -114.98, Epsilon: 0.41
# Episode: 981, Ep Step: 200, Raw Reward: -114.10, Epsilon: 0.41
# Episode: 982, Ep Step: 200, Raw Reward: -114.74, Epsilon: 0.41
# Episode: 983, Ep Step: 200, Raw Reward: -109.65, Epsilon: 0.40
# Episode: 984, Ep Step: 200, Raw Reward: -110.63, Epsilon: 0.40
# Episode: 985, Ep Step: 200, Raw Reward: -109.11, Epsilon: 0.40
# Episode: 986, Ep Step: 200, Raw Reward: -111.14, Epsilon: 0.40
# Episode: 987, Ep Step: 200, Raw Reward: -111.94, Epsilon: 0.40
# Episode: 988, Ep Step: 200, Raw Reward: -107.00, Epsilon: 0.40
# Episode: 989, Ep Step: 200, Raw Reward: -111.40, Epsilon: 0.40
# Episode: 990, Ep Step: 200, Raw Reward: -106.47, Epsilon: 0.40
# Episode: 991, Ep Step: 200, Raw Reward: -106.55, Epsilon: 0.40
# Episode: 992, Ep Step: 200, Raw Reward: -110.90, Epsilon: 0.40
# Episode: 993, Ep Step: 200, Raw Reward: -110.08, Epsilon: 0.40
# Episode: 994, Ep Step: 200, Raw Reward: -108.03, Epsilon: 0.40
# Episode: 995, Ep Step: 200, Raw Reward: -111.14, Epsilon: 0.40
# Episode: 996, Ep Step: 200, Raw Reward: -103.48, Epsilon: 0.40
# Episode: 997, Ep Step: 200, Raw Reward: -109.98, Epsilon: 0.40
# Episode: 998, Ep Step: 200, Raw Reward: -113.51, Epsilon: 0.40
# Episode: 999, Ep Step: 200, Raw Reward: -113.46, Epsilon: 0.40
#
# Model saved
#
# Episode: 1000, Ep Step: 200, Raw Reward: -114.17, Epsilon: 0.40
